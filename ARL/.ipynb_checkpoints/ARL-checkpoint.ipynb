# %% [markdown]
# ## ДЗ на тему "Ассоциативные правила"

# %% [markdown]
# > **Выполнил:** Ларин А.В.<br>
# > **Группа:** М8О-103М-20<br>

# %% [markdown]
# ### Apriori Algorithm

# %%
import pandas as pd
# загрузим данные
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
# посомтрим на датасет
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
dataset.fillna(method = 'ffill',axis = 1, inplace = True)
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs              eggs          eggs
# 2        chutney    chutney     chutney           chutney       chutney
# 3         turkey    avocado     avocado           avocado       avocado
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5          6               7             8             9   \
# 0  whole weat flour       yams  cottage cheese  energy drink  tomato juice
# 1              eggs       eggs            eggs          eggs          eggs
# 2           chutney    chutney         chutney       chutney       chutney
# 3           avocado    avocado         avocado       avocado       avocado
# 4         green tea  green tea       green tea     green tea     green tea
#
#                10         11         12         13             14         15  \
# 0  low fat yogurt  green tea      honey      salad  mineral water     salmon
# 1            eggs       eggs       eggs       eggs           eggs       eggs
# 2         chutney    chutney    chutney    chutney        chutney    chutney
# 3         avocado    avocado    avocado    avocado        avocado    avocado
# 4       green tea  green tea  green tea  green tea      green tea  green tea
#
#                   16               17         18         19
# 0  antioxydant juice  frozen smoothie    spinach  olive oil
# 1               eggs             eggs       eggs       eggs
# 2            chutney          chutney    chutney    chutney
# 3            avocado          avocado    avocado    avocado
# 4          green tea        green tea  green tea  green tea

# %%
#создаим из них матрицу
transactions = []
for i in range(0, 1001): 
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])
#загружаем apriori
from apyori import apriori, dump_as_json
# и обучимся правилам. Обратите внимание, что пороговые значения мы вибираем сами в зависимости от того,
# насколкьо "сильные" правила мы хотим получить
# min_support -- минимальный support для правил (dtype = float).
# min_confidence -- минимальное значение confidence для правил (dtype = float)
# min_lift -- минимальный lift (dtype = float)
# max_length -- максимальная длина itemset (вспоминаем про k-itemset)  (dtype = integer)

result = list(apriori(transactions, min_support = 0.003, min_confidence = 0.2))

# %%
import shutil, os 
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
import json #преобразовывать будем в json, используя встроенные в модуль методы
output = []
for RelationRecord in result:
    o = StringIO()
    dump_as_json(RelationRecord, o)
    output.append(json.loads(o.getvalue()))
data_df = pd.DataFrame(output)
# и взгялнем на итоги
pd.set_option('display.max_colwidth', None)

from IPython.display import display, HTML

display(HTML(data_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>items</th>
#       <th>support</th>
#       <th>ordered_statistics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[eggs]</td>
#       <td>0.207792</td>
#       <td>[{'items_base': [], 'items_add': ['eggs'], 'confidence': 0.2077922077922078, 'lift': 1.0}]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[mineral water]</td>
#       <td>0.244755</td>
#       <td>[{'items_base': [], 'items_add': ['mineral water'], 'confidence': 0.24475524475524477, 'lift': 1.0}]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[almonds, burgers]</td>
#       <td>0.009990</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['burgers'], 'confidence': 0.35714285714285715, 'lift': 4.46875}]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[almonds, chocolate]</td>
#       <td>0.007992</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['chocolate'], 'confidence': 0.2857142857142857, 'lift': 1.5132275132275133}]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[almonds, eggs]</td>
#       <td>0.010989</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['eggs'], 'confidence': 0.3928571428571429, 'lift': 1.890625}]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[almonds, french fries]</td>
#       <td>0.005994</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['french fries'], 'confidence': 0.21428571428571427, 'lift': 1.340625}]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[almonds, green tea]</td>
#       <td>0.005994</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['green tea'], 'confidence': 0.21428571428571427, 'lift': 1.5212765957446808}]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[almonds, ground beef]</td>
#       <td>0.006993</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['ground beef'], 'confidence': 0.25, 'lift': 2.5535714285714284}]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[almonds, milk]</td>
#       <td>0.009990</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['milk'], 'confidence': 0.35714285714285715, 'lift': 2.628676470588235}]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[almonds, mineral water]</td>
#       <td>0.012987</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['mineral water'], 'confidence': 0.4642857142857143, 'lift': 1.896938775510204}]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[almonds, soup]</td>
#       <td>0.007992</td>
#       <td>[{'items_base': ['almonds'], 'items_add': ['soup'], 'confidence': 0.2857142857142857, 'lift': 3.917808219178082}]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[avocado, chocolate]</td>
#       <td>0.009990</td>
#       <td>[{'items_base': ['avocado'], 'items_add': ['chocolate'], 'confidence': 0.2857142857142857, 'lift': 1.5132275132275133}]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[avocado, french fries]</td>
#       <td>0.008991</td>
#       <td>[{'items_base': ['avocado'], 'items_add': ['french fries'], 'confidence': 0.2571428571428572, 'lift': 1.6087500000000001}]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[avocado, green tea]</td>
#       <td>0.008991</td>
#       <td>[{'items_base': ['avocado'], 'items_add': ['green tea'], 'confidence': 0.2571428571428572, 'lift': 1.825531914893617}]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[avocado, milk]</td>
#       <td>0.013986</td>
#       <td>[{'items_base': ['avocado'], 'items_add': ['milk'], 'confidence': 0.39999999999999997, 'lift': 2.9441176470588233}]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[avocado, mineral water]</td>
#       <td>0.013986</td>
#       <td>[{'items_base': ['avocado'], 'items_add': ['mineral water'], 'confidence': 0.39999999999999997, 'lift': 1.6342857142857141}]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[bacon, chocolate]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['bacon'], 'items_add': ['chocolate'], 'confidence': 0.5, 'lift': 2.6481481481481484}]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[barbecue sauce, eggs]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['barbecue sauce'], 'items_add': ['eggs'], 'confidence': 0.4444444444444444, 'lift': 2.138888888888889}]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[barbecue sauce, mineral water]</td>
#       <td>0.004995</td>
#       <td>[{'items_base': ['barbecue sauce'], 'items_add': ['mineral water'], 'confidence': 0.5555555555555555, 'lift': 2.2698412698412693}]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[barbecue sauce, soup]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['barbecue sauce'], 'items_add': ['soup'], 'confidence': 0.4444444444444444, 'lift': 6.094368340943683}]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[barbecue sauce, turkey]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['barbecue sauce'], 'items_add': ['turkey'], 'confidence': 0.4444444444444444, 'lift': 5.6315049226441625}]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[black tea, eggs]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['eggs'], 'confidence': 0.4, 'lift': 1.925}]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[black tea, green tea]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['green tea'], 'confidence': 0.4, 'lift': 2.8397163120567375}]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[black tea, ground beef]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['ground beef'], 'confidence': 0.4, 'lift': 4.085714285714286}]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[black tea, herb &amp; pepper]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['herb &amp; pepper'], 'confidence': 0.4, 'lift': 5.802898550724638}]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[black tea, milk]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['milk'], 'confidence': 0.4, 'lift': 2.9441176470588237}]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[black tea, mineral water]</td>
#       <td>0.004995</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['mineral water'], 'confidence': 0.5, 'lift': 2.0428571428571427}]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[black tea, spaghetti]</td>
#       <td>0.005994</td>
#       <td>[{'items_base': ['black tea'], 'items_add': ['spaghetti'], 'confidence': 0.6, 'lift': 3.2290322580645157}]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[blueberries, eggs]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['blueberries'], 'items_add': ['eggs'], 'confidence': 0.4, 'lift': 1.925}]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[blueberries, spaghetti]</td>
#       <td>0.004995</td>
#       <td>[{'items_base': ['blueberries'], 'items_add': ['spaghetti'], 'confidence': 0.5, 'lift': 2.6908602150537635}]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>[body spray, french fries]</td>
#       <td>0.004995</td>
#       <td>[{'items_base': ['body spray'], 'items_add': ['french fries'], 'confidence': 0.3846153846153846, 'lift': 2.40625}]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>[body spray, green tea]</td>
#       <td>0.005994</td>
#       <td>[{'items_base': ['body spray'], 'items_add': ['green tea'], 'confidence': 0.4615384615384615, 'lift': 3.2765957446808507}]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>[body spray, soup]</td>
#       <td>0.004995</td>
#       <td>[{'items_base': ['body spray'], 'items_add': ['soup'], 'confidence': 0.3846153846153846, 'lift': 5.273972602739725}]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>[brownies, cake]</td>
#       <td>0.003996</td>
#       <td>[{'items_base': ['brownies'], 'items_add': ['cake'], 'confidence': 0.2, 'lift': 2.6342105263157896}]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>[brownies, chocolate]</td>
#       <td>0.005994</td>
#       <td>[{'items_base': ['brownies'], 'items_add': ['chocolate'], 'conf

# %% [markdown]
# ### ECLAT Algorithm

# %%
import numpy as np
"""
Класс инициируется 3мя параметрами:
- min_supp - минимальный support  который мы рассматриваем для ItemSet. Рассчитывается как % от количества транзакций
- max_items - максимальное количество елементов в нашем ItemSet
- min_items - минимальное количество элементов ItemSet
"""
class Eclat:
    #инициализация объекта класса
    def __init__(self, min_support = 0.01, max_items = 5, min_items = 2):
        self.min_support = min_support
        self.max_items = max_items
        self.min_items = min_items
        self.item_lst = list()
        self.item_len = 0
        self.item_dict = dict()
        self.final_dict = dict()
        self.data_size = 0
    
    #создание словаря из ненулевых объектов из всех транзакций (вертикальный датасет)
    def read_data(self, dataset):
        for index, row in dataset.iterrows():
            row_wo_na = set(row[0])
            for item in row_wo_na:
                item = item.strip()
                if item in self.item_dict:
                    self.item_dict[item][0] += 1
                else:
                    self.item_dict.setdefault(item, []).append(1)
                self.item_dict[item].append(index)
        #задаем переменные экземпляра (instance variables)
        self.data_size = dataset.shape[0]
        self.item_lst = list(self.item_dict.keys())
        self.item_len = len(self.item_lst)
        self.min_support = self.min_support * self.data_size
        #print ("min_supp", self.min_support)
        
    #рекурсивный метод для поиска всех ItemSet по алгоритму Eclat
    #структура данных: {Item: [Supp number, tid1, tid2, tid3, ...]}
    def recur_eclat(self, item_name, tids_array, minsupp, num_items, k_start):
        if tids_array[0] >= minsupp and num_items <= self.max_items:
            for k in range(k_start+1, self.item_len):
                if self.item_dict[self.item_lst[k]][0] >= minsupp:
                    new_item = item_name + " | " + self.item_lst[k]
                    new_tids = np.intersect1d(tids_array[1:], self.item_dict[self.item_lst[k]][1:])
                    new_tids_size = new_tids.size
                    new_tids = np.insert(new_tids, 0, new_tids_size)
                    if new_tids_size >= minsupp:
                        if num_items >= self.min_items: self.final_dict.update({new_item: new_tids})
                        self.recur_eclat(new_item, new_tids, minsupp, num_items+1, k)
    
    #последовательный вызов функций определенных выше
    def fit(self, dataset):
        i = 0
        self.read_data(dataset)
        for w in self.item_lst:
            self.recur_eclat(w, self.item_dict[w], self.min_support, 2, i)
            i+=1
        return self
        
    #вывод в форме словаря {ItemSet: support(ItemSet)}
    def transform(self):
        return {k: "{0:.4f}%".format((v[0]+0.0)/self.data_size*100) for k, v in self.final_dict.items()}

# %%
#создадим экземпляр класса с нужными нам параметрами
model = Eclat(min_support = 0.01, max_items = 4, min_items = 3)

# %%
#обучим
model.fit(dataset)
#и визуализируем результаты
model.transform()
# Out:
# {'m | h | s': '5.5726%',
#  'm | h | s | p': '5.0527%',
#  'm | h | s | r': '5.5326%',
#  'm | h | s | i': '4.7594%',
#  'm | h | s | e': '1.2265%',
#  'm | h | s | n': '1.1065%',
#  'm | h | s | ': '1.2265%',
#  'm | h | p': '5.9059%',
#  'm | h | p | r': '5.0127%',
#  'm | h | p | i': '4.3328%',
#  'm | h | p | e': '1.5598%',
#  'm | h | p | n': '1.5331%',
#  'm | h | p | c': '1.5331%',
#  'm | h | p | a': '1.5731%',
#  'm | h | r': '5.5993%',
#  'm | h | r | i': '4.8260%',
#  'm | h | r | e': '1.2665%',
#  'm | h | r | n': '1.1065%',
#  'm | h | r | ': '1.2665%',
#  'm | h | i': '4.9727%',
#  'm | h | g': '1.0665%',
#  'm | h | g | a': '1.0665%',
#  'm | h | e': '2.1464%',
#  'm | h | e | n': '1.9597%',
#  'm | h | e | c': '1.6931%',
#  'm | h | e | ': '1.2932%',
#  'm | h | e | a': '1.7198%',
#  'm | h | n': '1.9597%',
#  'm | h | n | c': '1.5331%',
#  'm | h | n | ': '1.1065%',
#  'm | h | n | a': '1.5331%',
#  'm | h | c': '1.6931%',
#  'm | h | c | a': '1.6931%',
#  'm | h | ': '1.4398%',
#  'm | h |  | a': '1.0132%',
#  'm | h | a': '3.4795%',
#  'm | s | p': '5.0527%',
#  'm | s | p | r': '5.0127%',
#  'm | s | p | i': '4.3328%',
#  'm | s | r': '5.5326%',
#  'm | s | r | i': '4.7594%',
#  'm | s | r | e': '1.1998%',
#  'm | s | r | n': '1.1065%',
#  'm | s | r | ': '1.1998%',
#  'm | s | i': '6.3192%',
#  'm | s | i | e': '1.0665%',
#  'm | s | i | n': '1.4665%',
#  'm | s | i | f': '1.3465%',
#  'm | s | e': '5.5593%',
#  'm | s | e | n': '1.3332%',
#  'm | s | e | c': '1.0932%',
#  'm | s | e | t': '4.5594%',
#  'm | s | e | l': '1.0665%',
#  'm | s | e | ': '2.0664%',
#  'm | s | e | a': '5.0260%',
#  'm | s | e | o': '3.8528%',
#  'm | s | u': '1.4931%',
#  'm | s | n': '2.7863%',
#  'm | s | n | ': '1.1065%',
#  'm | s | n | a': '1.3332%',
#  'm | s | n | f': '1.3465%',
#  'm | s | n | o': '1.1199%',
#  'm | s | c': '1.0932%',
#  'm | s | c | ': '1.0932%',
#  'm | s | c | a': '1.0932%',
#  'm | s | t': '4.5594%',
#  'm | s | t | ': '1.2932%',
#  'm | s | t | a': '4.1328%',
#  'm | s | t | o': '3.5995%',
#  'm | s | l': '1.5998%',
#  'm | s | l | a': '1.4931%',
#  'm | s | ': '2.0664%',
#  'm | s |  | a': '1.6398%',
#  'm | s | a': '5.8925%',
#  'm | s | a | o': '3.8662%',
#  'm | s | f': '1.3465%',
#  'm | s | o': '4.3994%',
#  'm | p | r': '5.0127%',
#  'm | p | r | i': '4.3328%',
#  'm | p | i': '4.3328%',
#  'm | p | e': '1.5598%',
#  'm | p | e | n': '1.5331%',
#  'm | p | e | c': '1.5331%',
#  'm | p | e | a': '1.5598%',
#  'm | p | n': '1.5331%',
#  'm | p | n | c': '1.5331%',
#  'm | p | n | a': '1.5331%',
#  'm | p | c': '1.5331%',
#  'm | p | c | a': '1.5331%',
#  'm | p | a': '1.5731%',
#  'm | r | i': '12.5983%',
#  'm | r | i | e': '8.2656%',
#  'm | r | i | n': '8.1989%',
#  'm | r | i | t': '8.2656%',
#  'm | r | i | l': '7.7590%',
#  'm | r | i | ': '8.2656%',
#  'm | r | i | w': '7.6923%',
#  'm | r | i | a': '7.8390%',
#  'm | r | e': '9.2788%',
#  'm | r | e | n': '9.0655%',
#  'm | r | e | c': '1.0399%',
#  'm | r | e | t': '8.2656%',
#  'm | r | e | l': '7.9856%',
#  'm | r | e | ': '9.2254%',
#  'm | r | e | w': '7.6923%',
#  'm | r | e | a': '8.8522%',
#  'm | r | n': '9.0655%',
#  'm | r | n | t': '8.1989%',
#  'm | r | n | l': '7.8789%',
#  'm | r | n | ': '9.0655%',
#  'm | r | n | w': '7.6923%',
#  'm | r | n | a': '8.6388%',
#  'm | r | c': '1.0399%',
#  'm | r | c | ': '1.0265%',
#  'm | r | c | a': '1.0399%',
#  'm | r | t': '8.2656%',
#  'm | r | t | l': '7.7590%',
#  'm | r | t | ': '8.2656%',
#  'm | r | t | w': '7.6923%',
#  'm | r | t | a': '7.8390%',
#  'm | r | l': '7.9856%',
#  'm | r | l | ': '7.9456%',
#  'm | r | l | w': '7.6923%',
#  'm | r | l | a': '7.9856%',
#  'm | r | ': '9.2254%',
#  'm | r |  | w': '7.6923%',
#  'm | r |  | a': '8.7988%',
#  'm | r | w': '7.6923%',
#  'm | r | w | a': '7.6923%',
#  'm | r | a': '8.8522%',
#  'm | i | e': '9.0655%',
#  'm | i | e | n': '8.3189%',
#  'm | i | e | t': '8.9455%',
#  'm | i | e | l': '8.2789%',
#  'm | i | e | ': '8.9455%',
#  'm | i | e | w': '7.6923%',
#  'm | i | e | a': '8.6388%',
#  'm | i | u': '1.0799%',
#  'm | i | n': '9.5587%',
#  'm | i | n | t': '8.5189%',
#  'm | i | n | l': '7.8789%',
#  'm | i | n | ': '8.3855%',
#  'm | i | n | w': '7.6923%',
#  'm | i | n | a': '8.0789%',
#  'm | i | n | f': '1.5331%',
#  'm | i | t': '9.4121%',
#  'm | i | t | l': '8.6122%',
#  'm | i | t | ': '9.2788%',
#  'm | i | t | w': '7.6923%',
#  'm | i | t | a': '8.8522%',
#  'm | i | k': '2.5997%',
#  'm | i | k | l': '2.5997%',
#  'm | i | l': '11.0252%',
#  'm | i | l | ': '8.6122%',
#  'm | i | l | w': '7.6923%',
#  'm | i | l | a': '8.6122%',
#  'm | i | ': '9.2788%',
#  'm | i |  | w': '7.6923%',
#  'm | i |  | a': '8.8522%',
#  'm | i | w': '7.6923%',
#  'm | i | w | a': '7.6923%',
#  'm | i | a': '8.9721%',
#  'm | i | f': '1.5331%',
#  'm | b | e': '1.1865%',
#  'm | b | e | l': '1.1865%',
#  'm | b | e | a': '1.1865%',
#  'm | b | l': '1.1865%',
#  'm | b | l | a': '1.1865%',
#  'm | b | a': '1.1865%',
#  'm | g | e': '1.7731%',
#  'm | g | e | n': '1.1865%',
#  'm | g | e | c': '1.1065%',
#  'm | g | e | a': '1.7731%',
#  'm | g | n': '1.1865%',
#  'm | g | n | c': '1.0399%',
#  'm | g | n | a': '1.1865%',
#  'm | g | c': '1.1065%',
#  'm | g | c | a': '1.1065%',
#  'm | g | a': '1.9197%',
#  'm | e | n': '10.1453%',
#  'm | e | n | c': '1.7198%',
#  'm | e | n | t': '8.1989%',
#  'm | e | n | l': '7.9856%',
#  'm | e | n | ': '9.0655%',
#  'm | e | n | w': '7.6923%',
#  'm | e | n | a': '9.6121%',
#  'm | e | c': '2.3730%',
#  'm | e | c | ': '1.5065%',
#  'm | e | c | a': '2.3730%',
#  'm | e | t': '12.5717%',
#  'm | e | t | l': '8.7322%',
#  'm | e | t | ': '9.2921%',
#  'm | e | t | w': '7.6923%',
#  'm | e | t | a': '12.1450%',
#  'm | e | t | o': '3.7728%',
#  'm | e | l': '9.0655%',
#  'm | e | l | ': '8.4655%',
#  'm | e | l | w': '7.6923%',
#  'm | e | l | a': '8.9588%',
#  'm | e | ': '10.2520%',
#  'm | e |  | w': '7.6923%',
#  'm | e |  | a': '9.8254%',
#  'm | e |  | o': '1.2132%',
#  'm | e | w': '7.6923%',
#  'm | e | w | a': '7.6923%',
#  'm | e | a': '14.1314%',
#  'm | e | a | o': '3.6795%',
#  'm | e | o': '4.2128%',
#  'm | n | c': '1.7198%',
#  'm | n | c | a': '1.7198%',
#  'm | n | t': '8.5189%',
#  'm | n | t | l': '7.8789%',
#  'm | n | t | ': '8.3855%',
#  'm | n | t | w': '7.6923%',
#  'm | n | t | a': '7.9589%',
#  'm | n | l': '8.7055%',
#  'm | n | l | ': '8.0656%',
#  'm | n | l | w': '7.6923%',
#  'm | n | l | a': '8.5989%',
#  'm | n | l | o': '1.0132%',
#  'm | n | ': '9.2521%',
#  'm | n |  | w': '7.6923%',
#  'm | n |  | a': '8.8255%',
#  'm | n | w': '7.6923%',
#  'm | n | w | a': '7.6923%',
#  'm | n | a': '10.3320%',
#  'm | n | f': '1.7198%',
#  'm | n | o': '1.4931%',
#  'm | c | ': '1.5065%',
#  'm | c |  | a': '1.5065%',
#  'm | c | a': '2.3730%',
#  'm | t | l': '9.0655%',
#  'm | t | l | ': '8.6122%',
#  'm | t | l | w': '7.6923%',
#  'm | t | l | a': '9.0655%',
#  'm | t | ': '9.6254%',
#  'm | t |  | w': '7.6923%',
#  'm | t |  | a': '9.1988%',
#  'm | t |  | o': '1.2665%',
#  'm | t | w': '7.6923%',
#  'm | t | w | a': '7.6923%',
#  'm | t | a': '12.4783%',
#  'm | t | a | o': '3.6795%',
#  'm | t | o': '4.1061%',
#  'm | k | l': '2.5997%',
#  'm | l | ': '8.7988%',
#  'm | l |  | w': '7.6923%',
#  'm | l |  | a': '8.7988%',
#  'm | l | w': '7.6923%',
#  'm | l | w | a': '7.6923%',
#  'm | l | a': '9.8254%',
#  'm | l | a | o': '1.0665%',
#  'm | l | o': '1.1732%',
#  'm |  | w': '7.6923%',
#  'm |  | w | a': '7.6923%',
#  'm |  | a': '10.1586%',
#  'm |  | a | o': '1.1199%',
#  'm |  | o': '1.5465%',
#  'm | w | a': '7.6923%',
#  'm | a | o': '4.5594%',
#  'h | s | p': '11.1985%',
#  'h | s | p | r': '5.0127%',
#  'h | s | p | i': '9.1588%',
#  'h | s | p | g': '4.7194%',
#  'h | s | p | e': '6.7458%',
#  'h | s | p | t': '6.0659%',
#  'h | s | p | l': '1.2665%',
#  'h | s | p | ': '1.9731%',
#  'h | s | p | w': '1.2665%',
#  'h | s | p | a': '6.8658%',
#  'h | s | p | o': '1.3598%',
#  'h | s | r': '14.8114%',
#  'h | s | r | i': '8.1322%',
#  'h | s | r | g': '3.9995%',
#  'h | s | r | e': '10.4786%',
#  'h | s | r | u': '1.8131%',
#  'h | s | r | n': '6.1725%',
#  'h | s | r | c': '8.1456%',
#  'h | s | r | t': '6.2658%',
#  'h | s | r | ': '10.4786%',
#  'h | s | r | a': '6.7058%',
#  'h | s | r | f': '5.5859%',
#  'h | s | r | d': '4.0928%',
#  'h | s | i': '13.0649%',
#  'h | s | i | g': '4.7194%',
#  'h | s | i | e': '8.5189%',
#  'h | s | i | n': '3.8928%',
#  'h | s | i | c': '3.5862%',
#  'h | s | i | t': '5.2660%',
#  'h | s | i | ': '3.7995%',
#  'h | s | i | a': '5.0527%',
#  'h | s | i | f': '3.6795%',
#  'h | s | g': '9.3188%',
#  'h | s | g | e': '8.9455%',
#  'h | s | g | c': '4.2261%',
#  'h | s | g | t': '9.3188%',
#  'h | s | g | ': '4.5994%',
#  'h | s | g | a': '8.8522%',
#  'h | s | g | d': '4.2794%',
#  'h | s | e': '16.7711%',
#  'h | s | e | u': '1.8131%',
#  'h | s | e | n': '6.1725%',
#  'h | s | e | c': '8.3722%',
#  'h | s | e | t': '12.5583%',
#  'h | s | e | l': '1.3865%',
#  'h | s | e | ': '11.9984%',
#  'h | s | e | w': '1.2665%',
#  'h | s | e | a': '12.9983%',
#  'h | s | e | f': '5.5859%',
#  'h | s | e | o': '2.3064%',
#  'h | s | e | d': '4.1195%',
#  'h | s | u': '1.8131%',
#  'h | s | u | n': '1.7198%',
#  'h | s | u | t': '1.7198%',
#  'h | s | u | ': '1.8131%',
#  'h | s | u | a': '1.8131%',
#  'h | s | u | f': '1.7198%',
#  'h | s | n': '6.3858%',
#  'h | s | n | c': '4.2394%',
#  'h | s | n | t': '2.2397%',
#  'h | s | n | ': '6.1725%',
#  'h | s | n | a': '2.6130%',
#  'h | s | n | f': '5.3993%',
#  'h | s | c': '8.5855%',
#  'h | s | c | t': '4.3461%',
#  'h | s | c | ': '8.3722%',
#  'h | s | c | a': '5.2393%',
#  'h | s | c | f': '3.2529%',
#  'h | s | c | d': '4.0128%',
#  'h | s | t': '12.9849%',
#  'h | s | t | l': '1.4398%',
#  'h | s | t | ': '8.1589%',
#  'h | s | t | w': '1.2665%',
#  'h | s | t | a': '12.0917%',
#  'h | s | t | f': '2.1464%',
#  'h | s | t | o': '2.6396%',
#  'h | s | t | d': '4.3061%',
#  'h | s | l': '1.4398%',
#  'h | s | l | ': '1.3865%',
#  'h | s | l | w': '1.2665%',
#  'h | s | l | a': '1.4398%',
#  'h | s | l | o': '1.4398%',
#  'h | s | ': '12.3717%',
#  'h | s |  | w': '1.2665%',
#  'h | s |  | a': '8.2256%',
#  'h | s |  | f': '5.5859%',
#  'h | s |  | o': '2.6263%',
#  'h | s |  | d': '4.4927%',
#  'h | s | w': '1.3732%',
#  'h | s | w | a': '1.3732%',
#  'h | s | w | o': '1.2665%',
#  'h | s | a': '13.2782%',
#  'h | s | a | f': '1.9064%',
#  'h | s | a | o': '1.8531%',
#  'h | s | a | d': '4.2261%',
#  'h | s | f': '5.5859%',
#  'h | s | o': '2.7463%',
#  'h | s | d': '4.5994%',
#  'h | p | r': '8.1322%',
#  'h | p | r | i': '4.3594%',
#  'h | p | r | b': '3.1196%',
#  'h | p | r | e': '3.7995%',
#  'h | p | r | ': '3.7995%',
#  'h | p | r | &': '3.0929%',
#  'h | p | i': '9.1854%',
#  'h | p | i | g': '4.7194%',
#  'h | p | i | e': '4.7460%',
#  'h | p | i | t': '4.7460%',
#  'h | p | i | a': '4.8527%',
#  'h | p | b': '3.1196%',
#  'h | p | b | e': '3.1196%',
#  'h | p | b | ': '3.1196%',
#  'h | p | b | &': '3.0929%',
#  'h | p | g': '5.5726%',
#  'h | p | g | e': '5.5726%',
#  'h | p | g | t': '4.7194%',
#  'h | p | g | a': '5.5726%',
#  'h | p | e': '10.7319%',
#  'h | p | e | n': '1.5598%',
#  'h | p | e | c': '1.5465%',
#  'h | p | e | t': '6.1059%',
#  'h | p | e | l': '1.2665%',
#  'h | p | e | ': '5.0927%',
#  'h | p | e | w': '1.2665%',
#  'h | p | e | a': '7.6256%',
#  'h | p | e | o': '1.3732%',
#  'h | p | e | &': '3.0929%',
#  'h | p | n': '1.6664%',
#  'h | p | n | c': '1.6398%',
#  'h | p | n | a': '1.6664%',
#  'h | p | c': '1.6531%',
#  'h | p | c | a': '1.6398%',
#  'h | p | t': '6.1059%',
#  'h | p | t | l': '1.2665%',
#  'h | p | t | ': '1.3198%',
#  'h | p | t | w': '1.2665%',
#  'h | p | t | a': '6.0925%',
#  'h | p | t | o': '1.3732%',
#  'h | p | l': '1.2665%',
#  'h | p | l | ': '1.2665%',
#  'h | p | l | w': '1.2665%',
#  'h | p | l | a': '1.2665%',
#  'h | p | l | o': '1.2665%',
#  'h | p | ': '5.0927%',
#  'h | p |  | w': '1.2665%',
#  'h | p |  | a': '1.9997%',
#  'h | p |  | o': '1.3198%',
#  'h | p |  | &': '3.0929%',
#  'h | p | w': '1.2665%',
#  'h | p | w | a': '1.2665%',
#  'h | p | w | o': '1.2665%',
#  'h | p | a': '7.7456%',
#  'h | p | a | o': '1.3865%',
#  'h | p | o': '1.3865%',
#  'h | p | &': '3.0929%',
#  'h | r | i': '9.0921%',
#  'h | r | i | e': '4.7594%',
#  'h | r | i | n': '3.9461%',
#  'h | r | i | c': '4.3061%',
#  'h | r | i | t': '1.2665%',
#  'h | r | i | ': '4.7594%',
#  'h | r | i | f': '3.9195%',
#  'h | r | i | o': '1.1998%',
#  'h | r | b': '3.3462%',
#  'h | r | b | e': '3.3462%',
#  'h | r | b | ': '3.3462%',
#  'h | r | b | &': '3.0929%',
#  'h | r | g': '4.0661%',
#  'h | r | g | e': '4.0661%',
#  'h | r | g | c': '4.0661%',
#  'h | r | g | t': '4.0661%',
#  'h | r | g | ': '4.0661%',
#  'h | r | g | a': '3.9728%',
#  'h | r | g | d': '3.9061%',
#  'h | r | e': '14.7847%',
#  'h | r | e | u': '1.9197%',
#  'h | r | e | n': '6.4391%',
#  'h | r | e | c': '9.2254%',
#  'h | r | e | t': '7.2390%',
#  'h | r | e | l': '1.0665%',
#  'h | r | e | ': '14.7847%',
#  'h | r | e | a': '7.6790%',
#  'h | r | e | f': '5.9325%',
#  'h | r | e | o': '1.6398%',
#  'h | r | e | d': '4.2661%',
#  'h | r | e | &': '3.0929%',
#  'h | r | u': '1.9197%',
#  'h | r | u | n': '1.7198%',
#  'h | r | u | t': '1.8264%',
#  'h | r | u | ': '1.9197%',
#  'h | r | u | a': '1.9197%',
#  'h | r | u | f': '1.8264%',
#  'h | r | n': '6.4391%',
#  'h | r | n | c': '4.2661%',
#  'h | r | n | t': '2.2664%',
#  'h | r | n | ': '6.4391%',
#  'h | r | n | a': '2.4263%',
#  'h | r | n | f': '5.6392%',
#  'h | r | c': '9.2254%',
#  'h | r | c | t': '4.9593%',
#  'h | r | c | ': '9.2254%',
#  'h | r | c | a': '5.6392%',
#  'h | r | c | f': '3.4929%',
#  'h | r | c | o': '1.0799%',
#  'h | r | c | d': '4.0528%',
#  'h | r | t': '7.2390%',
#  'h | r | t | l': '1.0665%',
#  'h | r | t | ': '7.2390%',
#  'h | r | t | a': '6.7191%',
#  'h | r | t | f': '2.2530%',
#  'h | r | t | o': '1.5465%',
#  'h | r | t | d': '4.0795%',
#  'h | r | l': '1.0665%',
#  'h | r | l | ': '1.0665%',
#  'h | r | l | a': '1.0665%',
#  'h | r | ': '14.7847%',
#  'h | r |  | a': '7.6790%',
#  'h | r |  | f': '5.9325%',
#  'h | r |  | o': '1.6398%',
#  'h | r |  | d': '4.2661%',
#  'h | r |  | &': '3.0929%',
#  'h | r | a': '7.6790%',
#  'h | r | a | f': '2.0131%',
#  'h | r | a | o': '1.1199%',
#  'h | r | a | d': '4.2661%',
#  'h | r | f': '5.9325%',
#  'h | r | o': '1.6398%',
#  'h | r | d': '4.2661%',
#  'h | r | &': '3.0929%',
#  'h | i | g': '4.9327%',
#  'h | i | g | e': '4.7860%',
#  'h | i | g | t': '4.9327%',
#  'h | i | g | a': '4.9327%',
#  'h | i | e': '10.1586%',
#  'h | i | e | n': '4.6260%',
#  'h | i | e | c': '4.8927%',
#  'h | i | e | t': '6.0792%',
#  'h | i | e | ': '4.8527%',
#  'h | i | e | a': '5.5593%',
#  'h | i | e | f': '3.9195%',
#  'h | i | e | o': '1.1998%',
#  'h | i | n': '4.8394%',
#  'h | i | n | c': '4.2928%',
#  'h | i | n | ': '4.0395%',
#  'h | i | n | f': '3.9195%',
#  'h | i | c': '5.1726%',
#  'h | i | c | ': '4.3061%',
#  'h | i | c | a': '1.0265%',
#  'h | i | c | f': '3.4929%',
#  'h | i | t': '6.2258%',
#  'h | i | t | ': '1.5065%',
#  'h | i | t | a': '5.7059%',
#  'h | i | t | o': '1.3465%',
#  'h | i | l': '1.0265%',
#  'h | i | ': '4.9993%',
#  'h | i |  | f': '3.9195%',
#  'h | i |  | o': '1.3465%',
#  'h | i | w': '1.0665%',
#  'h | i | a': '5.9192%',
#  'h | i | f': '3.9195%',
#  'h | i | o': '1.3465%',
#  'h | b | e': '3.3462%',
#  'h | b | e | ': '3.3462%',
#  'h | b | e | &': '3.0929%',
#  'h | b | ': '3.3462%',
#  'h | b |  | &': '3.0929%',
#  'h | b | &': '3.0929%',
#  'h | g | e': '9.8654%',
#  'h | g | e | c': '5.1460%',
#  'h | g | e | t': '9.0121%',
#  'h | g | e | ': '4.2928%',
#  'h | g | e | a': '9.7720%',
#  'h | g | e | d': '3.9061%',
#  'h | g | c': '5.1460%',
#  'h | g | c | t': '4.2928%',
#  'h | g | c | ': '4.2928%',
#  'h | g | c | a': '5.0527%',
#  'h | g | c | d': '3.9061%',
#  'h | g | t': '9.5321%',
#  'h | g | t | ': '4.8127%',
#  'h | g | t | a': '9.0655%',
#  'h | g | t | d': '4.2794%',
#  'h | g | ': '4.8127%',
#  'h | g |  | a': '4.3461%',
#  'h | g |  | d': '4.2794%',
#  'h | g | a': '9.9187%',
#  'h | g | a | d': '3.9061%',
#  'h | g | d': '4.2794%',
#  'h | e | u': '2.0264%',
#  'h | e | u | n': '1.8131%',
#  'h | e | u | t': '1.9331%',
#  'h | e | u | ': '1.9197%',
#  'h | e | u | a': '1.9197%',
#  'h | e | u | f': '1.8264%',
#  'h | e | n': '8.4255%',
#  'h | e | n | c': '5.7992%',
#  'h | e | n | t': '2.4530%',
#  'h | e | n | ': '6.5325%',
#  'h | e | n | a': '3.2796%',
#  'h | e | n | f': '5.6392%',
#  'h | e | c': '16.2112%',
#  'h | e | c | t': '10.5053%',
#  'h | e | c | l': '6.1725%',
#  'h | e | c | ': '9.4521%',
#  'h | e | c | a': '11.9317%',
#  'h | e | c | f': '3.4929%',
#  'h | e | c | o': '6.5191%',
#  'h | e | c | d': '4.0528%',
#  'h | e | t': '18.9441%',
#  'h | e | t | l': '7.5457%',
#  'h | e | t | ': '8.8522%',
#  'h | e | t | w': '2.0931%',
#  'h | e | t | a': '18.2242%',
#  'h | e | t | f': '2.2530%',
#  'h | e | t | o': '8.3322%',
#  'h | e | t | d': '4.1061%',
#  'h | e | l': '7.5457%',
#  'h | e | l | ': '2.3330%',
#  'h | e | l | w': '1.9997%',
#  'h | e | l | a': '7.5457%',
#  'h | e | l | o': '7.4790%',
#  'h | e | ': '16.3978%',
#  'h | e |  | w': '2.3330%',
#  'h | e |  | a': '9.1988%',
#  'h | e |  | f': '5.9325%',
#  'h | e |  | o': '3.1596%',
#  'h | e |  | d': '4.2928%',
#  'h | e |  | &': '3.0929%',
#  'h | e | w': '2.3330%',
#  'h | e | w | a': '1.9997%',
#  'h | e | w | o': '1.9997%',
#  'h | e | a': '20.0373%',
#  'h | e | a | f': '2.0131%',
#  'h | e | a | o': '7.9056%',
#  'h | e | a | d': '4.2928%',
#  'h | e | f': '5.9325%',
#  'h | e | o': '8.7855%',
#  'h | e | d': '4.2928%',
#  'h | e | &': '3.0929%',
#  'h | u | n': '1.8131%',
#  'h | u | n | t': '1.8131%',
#  'h | u | n | ': '1.7198%',
#  'h | u | n | a': '1.7198%',
#  'h | u | n | f': '1.7198%',
#  'h | u | t': '1.9331%',
#  'h | u | t | ': '1.8264%',
#  'h | u | t | a': '1.8264%',
#  'h | u | t | f': '1.8264%',
#  'h | u | ': '1.9197%',
#  'h | u |  | a': '1.9197%',
#  'h | u |  | f': '1.8264%',
#  'h | u | a': '1.9197%',
#  'h | u | a | f': '1.8264%',
#  'h | u | f': '1.8264%',
#  'h | n | c': '6.0125%',
#  'h | n | c | ': '4.2661%',
#  'h | n | c | a': '1.7464%',
#  'h | n | c | f': '3.4929%',
#  'h | n | t': '2.4530%',
#  'h | n | t | ': '2.3597%',
#  'h | n | t | a': '1.7464%',
#  'h | n | t | f': '2.1464%',
#  'h | n | ': '6.5325%',
#  'h | n |  | a': '2.4263%',
#  'h | n |  | f': '5.6392%',
#  'h | n | a': '3.4929%',
#  'h | n | a | f': '1.7198%',
#  'h | n | f': '5.6392%',
#  'h | c | t': '10.5053%',
#  'h | c | t | l': '6.1725%',
#  'h | c | t | ': '5.1860%',
#  'h | c | t | a': '10.3053%',
#  'h | c | t | o': '6.4258%',
#  'h | c | t | d': '4.0528%',
#  'h | c | l': '6.2392%',
#  'h | c | l | a': '6.1725%',
#  'h | c | l | o': '6.1059%',
#  'h | c | ': '9.4521%',
#  'h | c |  | a': '5.8659%',
#  'h | c |  | f': '3.4929%',
#  'h | c |  | o': '1.3065%',
#  'h | c |  | d': '4.0528%',
#  'h | c | a': '12.1450%',
#  'h | c | a | o': '6.4258%',
#  'h | c | a | d': '4.1594%',
#  'h | c | f': '3.4929%',
#  'h | c | o': '6.5191%',
#  'h | c | d': '4.1594%',
#  'h | t | l': '7.7456%',
#  'h | t | l | ': '2.4797%',
#  'h | t | l | w': '1.9997%',
#  'h | t | l | a': '7.7456%',
#  'h | t | l | o': '7.6790%',
#  'h | t | ': '9.3721%',
#  'h | t |  | w': '2.0931%',
#  'h | t |  | a': '8.3855%',
#  'h | t |  | f': '2.2530%',
#  'h | t |  | o': '3.5862%',
#  'h | t |  | d': '4.4794%',
#  'h | t | w': '2.0931%',
#  'h | t | w | a': '1.9997%',
#  'h | t | w | o': '1.9997%',
#  'h | t | a': '18.4242%',
#  'h | t | a | f': '1.8264%',
#  'h | t | a | o': '8.0123%',
#  'h | t | a | d': '4.1061%',
#  'h | t | f': '2.2530%',
#  'h | t | o': '8.9055%',
#  'h | t | d': '4.4794%',
#  'h | l | ': '2.4797%',
#  'h | l |  | w': '1.9997%',
#  'h | l |  | a': '2.4797%',
#  'h | l |  | o': '2.4130%',
#  'h | l | w': '1.9997%',
#  'h | l | w | a': '1.9997%',
#  'h | l | w | o': '1.9997%',
#  'h | l | a': '7.7456%',
#  'h | l | a | o': '7.6790%',
#  'h | l | o': '7.6790%',
#  'h |  | w': '2.3330%',
#  'h |  | w | a': '1.9997%',
#  'h |  | w | o': '1.9997%',
#  'h |  | a': '9.3454%',
#  'h |  | a | f': '2.0131%',
#  'h |  | a | o': '2.7863%',
#  'h |  | a | d': '4.2928%',
#  'h |  | f': '5.9325%',
#  'h |  | o': '3.6795%',
#  'h |  | d': '4.6660%',
#  'h |  | &': '3.0929%',
#  'h | w | a': '2.1064%',
#  'h | w | a | o': '1.9997%',
#  'h | w | o': '1.9997%',
#  'h | a | f': '2.0131%',
#  'h | a | o': '8.1189%',
#  'h | a | d': '4.3994%',
#  's | p | r': '5.2926%',
#  's | p | r | i': '4.3861%',
#  's | p | i': '9.7187%',
#  's | p | i | g': '4.7727%',
#  's | p | i | e': '5.2793%',
#  's | p | i | t': '4.7727%',
#  's | p | i | a': '4.8793%',
#  's | p | g': '4.9860%',
#  's | p | g | e': '4.8660%',
#  's | p | g | t': '4.7727%',
#  's | p | g | a': '4.9860%',
#  's | p | e': '10.3720%',
#  's | p | e | n': '1.8931%',
#  's | p | e | c': '4.1594%',
#  's | p | e | t': '6.1192%',
#  's | p | e | k': '1.6264%',
#  's | p | e | l': '3.7328%',
#  's | p | e | ': '2.1197%',
#  's | p | e | w': '1.3198%',
#  's | p | e | a': '9.8654%',
#  's | p | e | o': '3.2529%',
#  's | p | u': '1.1598%',
#  's | p | u | o': '1.0399%',
#  's | p | n': '1.9997%',
#  's | p | n | c': '1.8531%',
#  's | p | n | k': '1.1199%',
#  's | p | n | a': '1.9997%',
#  's | p | c': '4.2661%',
#  's | p | c | k': '1.5731%',
#  's | p | c | l': '2.4130%',
#  's | p | c | a': '3.7595%',
#  's | p | c | o': '1.9064%',
#  's | p | t': '6.2792%',
#  's | p | t | l': '1.3198%',
#  's | p | t | ': '1.3465%',
#  's | p | t | w': '1.3198%',
#  's | p | t | a': '6.2792%',
#  's | p | t | o': '1.3465%',
#  's | p | k': '1.6264%',
#  's | p | k | a': '1.1199%',
#  's | p | l': '3.7328%',
#  's | p | l | ': '1.3198%',
#  's | p | l | w': '1.3198%',
#  's | p | l | a': '3.2262%',
#  's | p | l | o': '3.1729%',
#  's | p | ': '2.2130%',
#  's | p |  | w': '1.3198%',
#  's | p |  | a': '2.2130%',
#  's | p |  | o': '1.3065%',
#  's | p | w': '1.3198%',
#  's | p | w | a': '1.3198%',
#  's | p | w | o': '1.2665%',
#  's | p | a': '10.2786%',
#  's | p | a | o': '3.2796%',
#  's | p | o': '4.3194%',
#  's | r | i': '9.2388%',
#  's | r | i | e': '4.9060%',
#  's | r | i | n': '4.4127%',
#  's | r | i | c': '3.3729%',
#  's | r | i | t': '1.2932%',
#  's | r | i | ': '4.2261%',
#  's | r | i | w': '1.0532%',
#  's | r | i | f': '3.6795%',
#  's | r | b': '14.1181%',
#  's | r | b | g': '12.8650%',
#  's | r | b | e': '13.6915%',
#  's | r | b | u': '7.8789%',
#  's | r | b | n': '5.7192%',
#  's | r | b | t': '5.2926%',
#  's | r | b | l': '5.0260%',
#  's | r | b | ': '5.7592%',
#  's | r | b | a': '6.0792%',
#  's | r | b | f': '5.1593%',
#  's | r | b | o': '5.2926%',
#  's | r | b | z': '4.9727%',
#  's | r | b | v': '4.9727%',
#  's | r | g': '17.0511%',
#  's | r | g | e': '16.9311%',
#  's | r | g | u': '7.8256%',
#  's | r | g | n': '5.3193%',
#  's | r | g | c': '4.0261%',
#  's | r | g | t': '9.0255%',
#  's | r | g | l': '5.0260%',
#  's | r | g | ': '9.3321%',
#  's | r | g | a': '9.2788%',
#  's | r | g | f': '4.9727%',
#  's | r | g | o': '5.0660%',
#  's | r | g | z': '4.9727%',
#  's | r | g | v': '4.9727%',
#  's | r | g | d': '3.9061%',
#  's | r | e': '24.8367%',
#  's | r | e | u': '9.6121%',
#  's | r | e | n': '12.0784%',
#  's | r | e | c': '8.5455%',
#  's | r | e | t': '11.9851%',
#  's | r | e | l': '5.5326%',
#  's | r | e | ': '16.1445%',
#  's | r | e | w': '1.0532%',
#  's | r | e | a': '12.6516%',
#  's | r | e | f': '10.5586%',
#  's | r | e | o': '6.0125%',
#  's | r | e | z': '5.3993%',
#  's | r | e | v': '4.9727%',
#  's | r | e | d': '4.4661%',
#  's | r | u': '9.7320%',
#  's | r | u | n': '1.7198%',
#  's | r | u | t': '1.7198%',
#  's | r | u | ': '1.9597%',
#  's | r | u | a': '1.9997%',
#  's | r | u | f': '1.7198%',
#  's | r | n': '12.4117%',
#  's | r | n | c': '4.3594%',
#  's | r | n | t': '7.6390%',
#  's | r | n | l': '5.0260%',
#  's | r | n | ': '12.1051%',
#  's | r | n | a': '7.9589%',
#  's | r | n | f': '10.3720%',
#  's | r | n | o': '5.7992%',
#  's | r | n | z': '5.3993%',
#  's | r | n | v': '4.9727%',
#  's | r | c': '8.9188%',
#  's | r | c | t': '4.1594%',
#  's | r | c | ': '8.5455%',
#  's | r | c | a': '5.5726%',
#  's | r | c | f': '3.2529%',
#  's | r | c | d': '4.2394%',
#  's | r | t': '12.0251%',
#  's | r | t | l': '5.1460%',
#  's | r | t | ': '11.6651%',
#  's | r | t | a': '11.1318%',
#  's | r | t | f': '7.1191%',
#  's | r | t | o': '5.6526%',
#  's | r | t | z': '5.3993%',
#  's | r | t | v': '4.9727%',
#  's | r | t | d': '4.2794%',
#  's | r | l': '5.5326%',
#  's | r | l | ': '5.1460%',
#  's | r | l | a': '5.4793%',
#  's | r | l | f': '4.9727%',
#  's | r | l | o': '5.0927%',
#  's | r | l | z': '4.9727%',
#  's | r | l | v': '4.9727%',
#  's | r | ': '16.5711%',
#  's | r |  | a': '12.4250%',
#  's | r |  | f': '10.5586%',
#  's | r |  | o': '5.7192%',
#  's | r |  | z': '5.3993%',
#  's | r |  | v': '4.9727%',
#  's | r |  | d': '4.8127%',
#  's | r | w': '1.0532%',
#  's | r | a': '13.1582%',
#  's | r | a | f': '6.8791%',
#  's | r | a | o': '5.2393%',
#  's | r | a | z': '4.9727%',
#  's | r | a | v': '4.9727%',
#  's | r | a | d': '4.4394%',
#  's | r | f': '10.5586%',
#  's | r | f | o': '5.3993%',
#  's | r | f | z': '5.3993%',
#  's | r | f | v': '4.9727%',
#  's | r | o': '6.0659%',
#  's | r | o | z': '5.3993%',
#  's | r | o | v': '4.9727%',
#  's | r | z': '5.3993%',
#  's | r | z | v': '4.9727%',
#  's | r | v': '4.9727%',
#  's | r | d': '4.8127%',
#  's | i | b': '1.2665%',
#  's | i | b | e': '1.2665%',
#  's | i | g': '5.3593%',
#  's | i | g | e': '5.3593%',
#  's | i | g | t': '5.2926%',
#  's | i | g | a': '5.3593%',
#  's | i | e': '14.4381%',
#  's | i | e | n': '4.5327%',
#  's | i | e | c': '7.4790%',
#  's | i | e | t': '6.5325%',
#  's | i | e | k': '4.1594%',
#  's | i | e | l': '1.2532%',
#  's | i | e | ': '4.8127%',
#  's | i | e | w': '1.0532%',
#  's | i | e | a': '5.9192%',
#  's | i | e | f': '3.7462%',
#  's | i | e | o': '4.5727%',
#  's | i | n': '5.6659%',
#  's | i | n | c': '3.4662%',
#  's | i | n | ': '4.1061%',
#  's | i | n | f': '4.5994%',
#  's | i | c': '7.6923%',
#  's | i | c | k': '4.1061%',
#  's | i | c | ': '3.3729%',
#  's | i | c | f': '3.2529%',
#  's | i | c | o': '3.7195%',
#  's | i | t': '6.5325%',
#  's | i | t | ': '1.4931%',
#  's | i | t | a': '5.7326%',
#  's | i | k': '4.1594%',
#  's | i | k | o': '3.5995%',
#  's | i | l': '1.2532%',
#  's | i | ': '4.8127%',
#  's | i |  | f': '3.7462%',
#  's | i | w': '1.1598%',
#  's | i | a': '6.1325%',
#  's | i | f': '4.6660%',
#  's | i | o': '4.5727%',
#  's | b | g': '13.3849%',
#  's | b | g | e': '13.3049%',
#  's | b | g | u': '7.7856%',
#  's | b | g | n': '5.0793%',
#  's | b | g | t': '5.4926%',
#  's | b | g | l': '5.4926%',
#  's | b | g | ': '5.7059%',
#  's | b | g | a': '5.7059%',
#  's | b | g | f': '4.9727%',
#  's | b | g | o': '4.9727%',
#  's | b | g | z': '4.9727%',
#  's | b | g | v': '5.4926%',
#  's | b | e': '14.7180%',
#  's | b | e | u': '7.7990%',
#  's | b | e | n': '5.3859%',
#  's | b | e | t': '6.2525%',
#  's | b | e | l': '5.9859%',
#  's | b | e | ': '5.9192%',
#  's | b | e | a': '6.6791%',
#  's | b | e | f': '5.2260%',
#  's | b | e | o': '5.3460%',
#  's | b | e | z': '4.9727%',
#  's | b | e | v': '5.4926%',
#  's | b | u': '7.8789%',
#  's | b | n': '5.7192%',
#  's | b | n | t': '4.9727%',
#  's | b | n | l': '4.9727%',
#  's | b | n | ': '5.4126%',
#  's | b | n | a': '5.4126%',
#  's | b | n | f': '4.9727%',
#  's | b | n | o': '5.2793%',
#  's | b | n | z': '4.9727%',
#  's | b | n | v': '4.9727%',
#  's | b | t': '6.2525%',
#  's | b | t | l': '5.9325%',
#  's | b | t | ': '5.4926%',
#  's | b | t | a': '6.2525%',
#  's | b | t | f': '4.9727%',
#  's | b | t | o': '4.9727%',
#  's | b | t | z': '4.9727%',
#  's | b | t | v': '5.4926%',
#  's | b | l': '5.9859%',
#  's | b | l | ': '5.4926%',
#  's | b | l | a': '5.9325%',
#  's | b | l | f': '4.9727%',
#  's | b | l | o': '4.9727%',
#  's | b | l | z': '4.9727%',
#  's | b | l | v': '5.4926%',
#  's | b | ': '6.3458%',
#  's | b |  | a': '6.3458%',
#  's | b |  | f': '5.2260%',
#  's | b |  | o': '5.0527%',
#  's | b |  | z': '4.9727%',
#  's | b |  | v': '5.4926%',
#  's | b | a': '7.1057%',
#  's | b | a | f': '5.2260%',
#  's | b | a | o': '5.0527%',
#  's | b | a | z': '4.9727%',
#  's | b | a | v': '5.4926%',
#  's | b | f': '5.2260%',
#  's | b | f | o': '5.0393%',
#  's | b | f | z': '4.9727%',
#  's | b | f | v': '4.9727%',
#  's | b | o': '5.3593%',
#  's | b | o | z': '4.9727%',
#  's | b | o | v': '4.9727%',
#  's | b | z': '4.9727%',
#  's | b | z | v': '4.9727%',
#  's | b | v': '5.4926%',
#  's | g | e': '26.1832%',
#  's | g | e | u': '7.7056%',
#  's | g | e | n': '5.3859%',
#  's | g | e | c': '4.2528%',
#  's | g | e | t': '14.4914%',
#  's | g | e | l': '5.5459%',
#  's | g | e | ': '9.9987%',
#  's | g | e | a': '14.6914%',
#  's | g | e | f': '4.9727%',
#  's | g | e | o': '5.2926%',
#  's | g | e | z': '5.0393%',
#  's | g | e | v': '5.4926%',
#  's | g | e | d': '3.9061%',
#  's | g | u': '7.9856%',
#  's | g | n': '5.3859%',
#  's | g | n | t': '5.1193%',
#  's | g | n | l': '5.0260%',
#  's | g | n | ': '5.3193%',
#  's | g | n | a': '5.2926%',
#  's | g | n | f': '4.9727%',
#  's | g | n | o': '5.0660%',
#  's | g | n | z': '5.0393%',
#  's | g | n | v': '4.9727%',
#  's | g | c': '4.2528%',
#  's | g | c | t': '4.2261%',
#  's | g | c | ': '4.2528%',
#  's | g | c | a': '4.1594%',
#  's | g | c | d': '3.9061%',
#  's | g | t': '14.8647%',
#  's | g | t | l': '5.5459%',
#  ...}

# %% [markdown]
# ### FP-Growth Algorithm

# %%
#!pip install pyfpgrowth
import pyfpgrowth

# %%
#Сгенериуем паттерны
patterns = pyfpgrowth.find_frequent_patterns(transactions, 2)
#Выучим правила
rules = pyfpgrowth.generate_association_rules(patterns, 30);
#Покажем
rules
# Out:
# {('energy bar',
#   'whole wheat pasta'): ((' asparagus',
#    'burgers',
#    'chocolate',
#    'ground beef'), 143.0),
#  ('burgers', 'energy bar', 'shrimp'): (('body spray', 'french fries'), 55.0),
#  ('ground beef',
#   'soup',
#   'whole wheat pasta'): ((' asparagus',
#    'burgers',
#    'chocolate'), 95.33333333333333),
#  ('chocolate',
#   'energy bar',
#   'soup'): ((' asparagus',
#    'burgers',
#    'ground beef',
#    'shrimp',
#    'whole wheat pasta'), 39.0),
#  ('chocolate', 'energy bar', 'shrimp'): (('body spray', 'burgers'), 82.5),
#  ('chocolate',
#   'ground beef',
#   'shrimp'): ((' asparagus',
#    'burgers',
#    'energy bar',
#    'whole wheat pasta'), 143.0),
#  ('burgers',
#   'chocolate',
#   'energy bar',
#   'soup'): ((' asparagus',
#    'ground beef',
#    'shrimp',
#    'whole wheat pasta'), 39.0),
#  ('burgers', 'chocolate', 'energy bar', 'shrimp'): (('body spray',), 82.5),
#  ('burgers',
#   'chocolate',
#   'ground beef',
#   'soup'): ((' asparagus', 'energy bar', 'shrimp', 'whole wheat pasta'), 39.0),
#  ('chocolate',
#   'shrimp',
#   'whole wheat pasta'): ((' asparagus',
#    'burgers',
#    'energy bar',
#    'ground beef'),
#   143.0),
#  ('chocolate',
#   'soup',
#   'whole wheat pasta'): ((' asparagus',
#    'burgers',
#    'energy bar',
#    'ground beef',
#    'shrimp'), 39.0),
#  ('chocolate',
#   'shrimp',
#   'soup',
#   'whole wheat pasta'): ((' asparagus',
#    'burgers',
#    'energy bar',
#    'ground beef'), 39.0),
#  ('frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'mineral water'): (('almonds', 'olive oil', 'soup'), 39.0),
#  ('chocolate', 'escalope', 'tomato sauce'): (('mineral water', 'mint'), 52.5),
#  ('mineral water', 'red wine', 'turkey'): (('barbecue sauce',), 55.0),
#  ('bramble', 'mineral water'): (('eggs',), 32.94117647058823),
#  ('eggs', 'mineral water', 'red wine', 'turkey'): (('bramble',), 60.0),
#  ('bramble', 'eggs', 'red wine'): (('mineral water',), 35.0),
#  ('bacon',
#   'yams'): (('grated cheese', 'mineral water', 'spinach', 'whole wheat pasta'),
#   143.0),
#  ('bacon',
#   'grated cheese'): (('mineral water',
#    'spinach',
#    'whole wheat pasta',
#    'yams'), 143.0),
#  ('eggs', 'french fries', 'ham', 'spaghetti'): (('light mayo',), 33.0),
#  ('green tea', 'mineral water', 'oil'): (('ham', 'mint'), 40.0),
#  ('chocolate', 'mineral water', 'olive oil', 'parmesan cheese'): (('bacon',),
#   60.0),
#  ('bacon', 'olive oil', 'parmesan cheese'): (('chocolate',), 35.0),
#  ('chocolate', 'olive oil', 'parmesan cheese'): (('bacon',),
#   37.333333333333336),
#  ('eggs', 'french fries', 'fresh tuna'): (('fresh bread', 'mineral water'),
#   60.0),
#  ('eggs', 'fresh tuna', 'olive oil'): (('mineral water', 'tomato juice'),
#   33.0),
#  ('fresh tuna', 'frozen smoothie', 'honey'): (('escalope',), 39.0),
#  ('black tea', 'mineral water'): (('shrimp',), 32.38095238095238),
#  ('green grapes', 'green tea', 'mineral water'): (('mint',), 60.0),
#  ('frozen smoothie', 'mineral water', 'yams'): (('energy drink',), 45.5),
#  ('eggs', 'mineral water', 'yams'): (('cake',), 68.0),
#  ('butter',
#   'frozen vegetables',
#   'spaghetti'): (('cauliflower',
#    'cooking oil',
#    'frozen smoothie',
#    'oil',
#    'olive oil',
#    'salmon'),
#   33.0),
#  ('frozen vegetables', 'oil'): (('magazines',), 95.33333333333333),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'salmon'): (('magazines', 'spaghetti'), 42.0),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'salmon',
#   'spaghetti'): (('magazines',), 42.0),
#  ('butter',
#   'frozen vegetables',
#   'salmon'): (('cauliflower',
#    'cooking oil',
#    'frozen smoothie',
#    'oil',
#    'olive oil',
#    'spaghetti'),
#   33.0),
#  ('butter',
#   'cooking oil',
#   'salmon'): (('cauliflower',
#    'frozen smoothie',
#    'frozen vegetables',
#    'oil',
#    'olive oil',
#    'spaghetti'), 33.0),
#  ('cooking oil',
#   'salmon',
#   'spaghetti'): (('cauliflower',
#    'frozen smoothie',
#    'frozen vegetables',
#    'olive oil'), 110.0),
#  ('cooking oil',
#   'frozen smoothie',
#   'frozen vegetables',
#   'spaghetti'): (('cauliflower', 'olive oil', 'salmon'), 110.0),
#  ('cooking oil', 'frozen vegetables', 'spaghetti'): (('cereals', 'honey'),
#   30.0),
#  ('butter',
#   'olive oil',
#   'spaghetti'): (('cauliflower',
#    'cooking oil',
#    'frozen smoothie',
#    'frozen vegetables',
#    'oil',
#    'salmon'),
#   33.0),
#  ('olive oil', 'salmon', 'spaghetti'): (('blueberries', 'burgers'),
#   95.33333333333333),
#  ('frozen smoothie',
#   'olive oil',
#   'spaghetti'): (('cake', 'chocolate', 'protein bar'), 55.0),
#  ('frozen smoothie',
#   'olive oil',
#   'salmon'): (('cauliflower', 'cooking oil', 'frozen vegetables'), 110.0),
#  ('cooking oil',
#   'frozen smoothie',
#   'olive oil',
#   'spaghetti'): (('cauliflower', 'frozen vegetables', 'salmon'), 110.0),
#  ('frozen vegetables', 'olive oil', 'salmon'): (('champagne', 'shrimp'), 82.5),
#  ('cooking oil',
#   'frozen vegetables',
#   'olive oil',
#   'spaghetti'): (('cauliflower', 'frozen smoothie', 'salmon'), 110.0),
#  ('cooking oil',
#   'frozen smoothie',
#   'frozen vegetables',
#   'olive oil'): (('cauliflower',), 110.0),
#  ('cooking oil',
#   'frozen smoothie',
#   'frozen vegetables',
#   'olive oil',
#   'spaghetti'): (('cauliflower', 'salmon'), 110.0),
#  ('burgers',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water'): (('asparagus', 'chocolate', 'light mayo', 'milk'), 39.0),
#  ('burgers',
#   'frozen vegetables',
#   'ground beef',
#   'milk',
#   'mineral water'): (('asparagus', 'chocolate', 'light mayo'), 39.0),
#  ('burgers',
#   'chocolate',
#   'frozen vegetables',
#   'milk',
#   'mineral water'): (('asparagus', 'light mayo'), 143.0),
#  ('burgers',
#   'chocolate',
#   'frozen vegetables',
#   'milk'): (('cereals', 'cooking oil', 'spaghetti', 'whole wheat rice'), 40.0),
#  ('chicken', 'chocolate bread'): (('pasta',), 37.77777777777778),
#  ('cake', 'grated cheese', 'mineral water'): (('chocolate bread',), 68.0),
#  ('cake', 'chocolate bread'): (('mineral water',), 37.77777777777778),
#  ('burgers',
#   'chicken',
#   'mineral water',
#   'olive oil'): (('almonds', 'extra dark chocolate'), 42.0),
#  ('burgers',
#   'chicken',
#   'mineral water',
#   'olive oil',
#   'shrimp'): (('cake', 'extra dark chocolate'), 42.0),
#  ('milk', 'olive oil', 'whole wheat pasta'): (('fresh bread', 'ground beef'),
#   40.0),
#  ('energy bar', 'pasta'): (('burgers', 'herb & pepper', 'salt', 'spaghetti'),
#   42.0),
#  ('energy bar',
#   'pasta',
#   'shrimp'): (('burgers',
#    'eggs',
#    'herb & pepper',
#    'mineral water',
#    'salt',
#    'spaghetti'), 42.0),
#  ('light mayo', 'salmon'): (('magazines',), 51.0),
#  ('grated cheese',
#   'milk',
#   'mineral water'): (('french wine', 'frozen vegetables'), 227.5),
#  ('grated cheese',
#   'milk',
#   'mineral water',
#   'soup'): (('french wine', 'frozen vegetables'), 52.5),
#  ('french wine',
#   'grated cheese',
#   'milk',
#   'mineral water'): (('frozen vegetables',), 30.333333333333332),
#  ('light cream',
#   'mineral water',
#   'red wine'): (('barbecue sauce', 'chicken', 'chocolate', 'oil', 'turkey'),
#   82.5),
#  ('chocolate',
#   'light cream',
#   'rice'): (('barbecue sauce',
#    'chicken',
#    'mineral water',
#    'oil',
#    'turkey'), 82.5),
#  ('mineral water',
#   'red wine',
#   'rice'): (('barbecue sauce', 'chocolate', 'turkey'), 82.5),
#  ('rice', 'turkey'): (('barbecue sauce',), 82.5),
#  ('light cream',
#   'rice',
#   'turkey'): (('barbecue sauce',
#    'chicken',
#    'chocolate',
#    'mineral water',
#    'oil'),
#   82.5),
#  ('chocolate', 'mineral water', 'turkey'): (('ground beef', 'olive oil'),
#   40.0),
#  ('chocolate', 'mineral water', 'red wine', 'turkey'): (('barbecue sauce',),
#   82.5),
#  ('light cream',
#   'mineral water',
#   'oil'): (('barbecue sauce', 'chicken', 'chocolate', 'turkey'), 82.5),
#  ('chocolate', 'mineral water', 'red wine', 'soup'): (('barbecue sauce',),
#   82.5),
#  ('oil', 'turkey'): (('barbecue sauce', 'chicken'), 55.0),
#  ('chicken',
#   'oil',
#   'rice'): (('barbecue sauce',
#    'chocolate',
#    'light cream',
#    'mineral water',
#    'turkey'),
#   82.5),
#  ('mineral water', 'rice', 'soup'): (('barbecue sauce', 'cookies'), 55.0),
#  ('chicken', 'chocolate', 'oil'): (('barbecue sauce', 'turkey'), 82.5),
#  ('chicken', 'light cream', 'turkey'): (('barbecue sauce', 'chocolate', 'oil'),
#   82.5),
#  ('chocolate',
#   'mineral water',
#   'soup',
#   'turkey'): (('barbecue sauce',
#    'chicken',
#    'light cream',
#    'oil',
#    'red wine'), 82.5),
#  ('green beans', 'soup'): (('milk',), 32.94117647058823),
#  ('cereals', 'chicken'): (('clothes accessories', 'mineral water'), 68.0),
#  ('clothes accessories', 'mineral water'): (('chicken',), 37.77777777777778),
#  ('grated cheese',
#   'shrimp',
#   'spaghetti'): (('carrots',
#    'ground beef',
#    'herb & pepper',
#    'mineral water'), 39.0),
#  ('grated cheese',
#   'herb & pepper',
#   'spaghetti'): (('carrots', 'ground beef', 'mineral water', 'shrimp'), 39.0),
#  ('grated cheese',
#   'ground beef',
#   'mineral water',
#   'spaghetti'): (('carrots', 'herb & pepper', 'shrimp'), 39.0),
#  ('grated cheese',
#   'mineral water',
#   'shrimp'): (('carrots', 'ground beef', 'herb & pepper'), 143.0),
#  ('grated cheese',
#   'ground beef',
#   'mineral water',
#   'shrimp'): (('carrots', 'herb & pepper'), 143.0),
#  ('grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'spaghetti'): (('carrots', 'ground beef', 'shrimp'), 39.0),
#  ('herb & pepper',
#   'mineral water',
#   'shrimp',
#   'spaghetti'): (('burgers', 'eggs', 'energy bar', 'pasta', 'salt'), 42.0),
#  ('ground beef',
#   'herb & pepper',
#   'mineral water',
#   'spaghetti'): (('green tea', 'toothpaste'), 40.0),
#  ('almonds',
#   'cake',
#   'shrimp'): (('burgers',
#    'chicken',
#    'extra dark chocolate',
#    'mineral water',
#    'olive oil'),
#   42.0),
#  ('burgers',
#   'cake',
#   'chicken',
#   'frozen vegetables'): (('extra dark chocolate',
#    'mineral water',
#    'shrimp'), 42.0),
#  ('almonds',
#   'chicken',
#   'shrimp'): (('extra dark chocolate',
#    'frozen vegetables',
#    'mineral water',
#    'olive oil'), 42.0),
#  ('almonds',
#   'burgers',
#   'cake'): (('chicken',
#    'extra dark chocolate',
#    'mineral water',
#    'olive oil',
#    'shrimp'), 42.0),
#  ('almonds', 'burgers', 'olive oil'): (('extra dark chocolate',), 42.0),
#  ('almonds',
#   'burgers',
#   'cake',
#   'olive oil'): (('chicken',
#    'extra dark chocolate',
#    'mineral water',
#    'shrimp'), 42.0),
#  ('almonds',
#   'olive oil',
#   'shrimp'): (('chicken',
#    'extra dark chocolate',
#    'frozen vegetables',
#    'mineral water'), 42.0),
#  ('frozen vegetables',
#   'olive oil',
#   'shrimp'): (('champagne', 'chocolate', 'mineral water'), 82.5),
#  ('burgers',
#   'cake',
#   'frozen vegetables',
#   'mineral water'): (('extra dark chocolate', 'olive oil', 'shrimp'), 42.0),
#  ('almonds',
#   'cake',
#   'mineral water',
#   'shrimp'): (('burgers', 'chicken', 'extra dark chocolate', 'olive oil'),
#   42.0),
#  ('burgers',
#   'frozen vegetables',
#   'mineral water',
#   'shrimp'): (('chicken', 'extra dark chocolate'), 42.0),
#  ('chicken',
#   'frozen vegetables',
#   'mineral water'): (('extra dark chocolate', 'shrimp'), 42.0),
#  ('frozen vegetables',
#   'mineral water',
#   'olive oil',
#   'shrimp'): (('champagne', 'chocolate'), 82.5),
#  ('almonds',
#   'mineral water',
#   'olive oil',
#   'shrimp'): (('chicken', 'extra dark chocolate', 'frozen vegetables'), 42.0),
#  ('almonds', 'burgers', 'shrimp'): (('chicken', 'extra dark chocolate'), 42.0),
#  ('almonds', 'burgers', 'chicken', 'shrimp'): (('extra dark chocolate',),
#   42.0),
#  ('eggs',
#   'salmon',
#   'turkey'): (('chicken',
#    'extra dark chocolate',
#    'mineral water',
#    'spaghetti'),
#   82.5),
#  ('chicken', 'mineral water', 'salmon'): (('cake',), 30.0),
#  ('chicken',
#   'eggs',
#   'mineral water',
#   'salmon'): (('frozen smoothie', 'shrimp', 'strawberries'), 82.5),
#  ('eggs',
#   'salmon',
#   'spaghetti'): (('blueberries', 'burgers', 'milk', 'olive oil'), 71.5),
#  ('eggs',
#   'mineral water',
#   'spaghetti',
#   'tomatoes'): (('extra dark chocolate',), 82.5),
#  ('mineral water',
#   'spaghetti',
#   'tomatoes',
#   'turkey'): (('chicken', 'extra dark chocolate'), 82.5),
#  ('eggs',
#   'mineral water',
#   'salmon',
#   'spaghetti'): (('chicken', 'extra dark chocolate', 'turkey'), 82.5),
#  ('eggs',
#   'mineral water',
#   'spaghetti',
#   'turkey'): (('chicken', 'extra dark chocolate', 'salmon'), 82.5),
#  ('chicken',
#   'eggs',
#   'mineral water',
#   'spaghetti'): (('extra dark chocolate', 'salmon', 'turkey'), 82.5),
#  ('chicken', 'mineral water', 'salmon', 'spaghetti'): (('cake', 'milk'), 40.0),
#  ('chicken',
#   'mineral water',
#   'spaghetti',
#   'turkey'): (('extra dark chocolate',), 82.5),
#  ('chicken',
#   'eggs',
#   'mineral water',
#   'spaghetti',
#   'turkey'): (('extra dark chocolate', 'salmon'), 82.5),
#  ('chocolate',
#   'eggs',
#   'ground beef',
#   'herb & pepper',
#   'milk'): (('light cream', 'spaghetti'), 45.5),
#  ('eggs', 'ground beef', 'milk', 'spaghetti'): (('cake',), 35.0),
#  ('chocolate',
#   'eggs',
#   'ground beef',
#   'milk',
#   'spaghetti'): (('herb & pepper', 'light cream'), 45.5),
#  ('chocolate', 'ground beef', 'herb & pepper', 'spaghetti'): (('light cream',),
#   121.33333333333333),
#  ('chocolate',
#   'eggs',
#   'ground beef',
#   'herb & pepper',
#   'spaghetti'): (('light cream', 'milk'), 45.5),
#  ('chocolate',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('ground beef', 'light cream'), 45.5),
#  ('chocolate',
#   'eggs',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('ground beef', 'light cream'), 45.5),
#  ('eggs',
#   'ground beef',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('light cream',), 182.0),
#  ('chocolate',
#   'eggs',
#   'ground beef',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('light cream',), 45.5),
#  ('eggs',
#   'ground beef',
#   'herb & pepper',
#   'milk'): (('light cream', 'spaghetti'), 91.0),
#  ('babies food', 'frozen vegetables', 'spaghetti'): (('chocolate',), 35.0),
#  ('butter', 'chocolate', 'eggs'): (('mayonnaise',), 30.333333333333332),
#  ('butter', 'chocolate', 'cottage cheese'): (('green tea', 'mayonnaise'),
#   32.5),
#  ('butter', 'chocolate', 'green tea'): (('mayonnaise',), 30.333333333333332),
#  ('chocolate', 'cottage cheese', 'mayonnaise'): (('green tea',),
#   30.333333333333332),
#  ('butter', 'chocolate', 'cottage cheese', 'mayonnaise'): (('green tea',),
#   30.333333333333332),
#  ('butter', 'chocolate', 'cooking oil'): (('escalope',), 40.0),
#  ('champagne', 'cooking oil'): (('salt', 'soup'), 182.0),
#  ('champagne', 'cooking oil', 'soup'): (('salt',), 182.0),
#  ('burgers',
#   'eggs',
#   'olive oil',
#   'soup'): (('blueberries', 'milk', 'salmon', 'spaghetti'), 39.0),
#  ('burgers',
#   'eggs',
#   'milk',
#   'olive oil'): (('blueberries', 'salmon', 'spaghetti'), 143.0),
#  ('burgers',
#   'eggs',
#   'milk',
#   'olive oil',
#   'soup'): (('blueberries', 'salmon', 'spaghetti'), 39.0),
#  ('burgers',
#   'eggs',
#   'olive oil'): (('blueberries', 'milk', 'salmon', 'spaghetti'), 71.5),
#  ('burgers', 'eggs', 'olive oil', 'spaghetti'): (('salt',), 42.0),
#  ('burgers',
#   'soup',
#   'spaghetti'): (('blueberries', 'eggs', 'milk', 'olive oil', 'salmon'), 39.0),
#  ('eggs', 'soup', 'spaghetti'): (('chocolate', 'frozen smoothie'), 60.0),
#  ('burgers', 'olive oil', 'spaghetti'): (('cake', 'milk'), 40.0),
#  ('eggs', 'milk', 'soup', 'spaghetti'): (('chocolate', 'frozen smoothie'),
#   60.0),
#  ('burgers', 'milk', 'olive oil', 'spaghetti'): (('cake',), 60.0),
#  ('eggs',
#   'milk',
#   'olive oil',
#   'spaghetti'): (('brownies', 'chocolate', 'mineral water'), 60.0),
#  ('burgers', 'milk', 'salmon'): (('blueberries', 'olive oil', 'spaghetti'),
#   143.0),
#  ('eggs', 'salmon', 'soup'): (('candy bars',), 82.5),
#  ('eggs',
#   'milk',
#   'salmon'): (('blueberries', 'burgers', 'olive oil', 'spaghetti'), 143.0),
#  ('burgers',
#   'eggs',
#   'salmon',
#   'soup'): (('blueberries', 'milk', 'olive oil', 'spaghetti'), 39.0),
#  ('olive oil',
#   'salmon',
#   'soup'): (('champagne', 'chocolate', 'mineral water', 'shrimp'), 82.5),
#  ('burgers', 'milk', 'olive oil', 'salmon'): (('blueberries', 'spaghetti'),
#   143.0),
#  ('salmon',
#   'soup',
#   'spaghetti'): (('blueberries',
#    'burgers',
#    'eggs',
#    'milk',
#    'olive oil'), 39.0),
#  ('milk', 'olive oil', 'salmon', 'spaghetti'): (('blueberries', 'burgers'),
#   143.0),
#  ('burgers', 'olive oil', 'salmon', 'spaghetti'): (('blueberries',), 143.0),
#  ('burgers', 'milk', 'olive oil', 'salmon', 'spaghetti'): (('blueberries',),
#   143.0),
#  ('eggs',
#   'olive oil',
#   'spaghetti'): (('champagne', 'french fries', 'light mayo'), 44.0),
#  ('eggs', 'mineral water', 'tomatoes', 'turkey'): (('blueberries',), 60.0),
#  ('blueberries', 'tomatoes', 'turkey'): (('eggs',), 35.0),
#  ('eggs', 'energy bar', 'mineral water'): (('low fat yogurt',), 33.0),
#  ('grated cheese', 'mineral water', 'tomatoes'): (('meatballs',), 68.0),
#  ('burgers',
#   'chocolate',
#   'honey'): (('cereals',
#    'cooking oil',
#    'frozen vegetables',
#    'whole wheat rice'),
#   60.0),
#  ('pepper',
#   'spaghetti',
#   'whole wheat rice'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'red wine'), 60.0),
#  ('chocolate',
#   'honey',
#   'spaghetti'): (('burgers',
#    'cereals',
#    'frozen vegetables',
#    'whole wheat rice'), 40.0),
#  ('burgers',
#   'chocolate',
#   'spaghetti',
#   'whole wheat rice'): (('cereals', 'cooking oil', 'frozen vegetables'), 60.0),
#  ('chocolate',
#   'pepper',
#   'spaghetti',
#   'whole wheat rice'): (('cereals',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'red wine'),
#   60.0),
#  ('honey',
#   'spaghetti',
#   'whole wheat rice'): (('french fries',
#    'frozen vegetables',
#    'mashed potato',
#    'pancakes'), 55.0),
#  ('chocolate',
#   'cooking oil',
#   'honey'): (('burgers',
#    'cereals',
#    'frozen vegetables',
#    'whole wheat rice'), 60.0),
#  ('burgers',
#   'chocolate',
#   'cooking oil'): (('corn', 'eggs', 'olive oil', 'turkey'), 45.5),
#  ('burgers',
#   'cooking oil',
#   'milk'): (('cereals', 'frozen vegetables', 'honey'), 60.0),
#  ('burgers',
#   'milk',
#   'pepper'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables',
#    'red wine',
#    'whole wheat rice'),
#   60.0),
#  ('cooking oil',
#   'milk',
#   'whole wheat rice'): (('burgers',
#    'cereals',
#    'chocolate',
#    'frozen vegetables',
#    'spaghetti'), 60.0),
#  ('burgers', 'chocolate', 'milk', 'whole wheat rice'): (('cereals',), 60.0),
#  ('burgers',
#   'chocolate',
#   'milk',
#   'spaghetti'): (('cereals',
#    'cooking oil',
#    'frozen vegetables',
#    'whole wheat rice'), 60.0),
#  ('burgers',
#   'milk',
#   'spaghetti',
#   'whole wheat rice'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'milk',
#   'spaghetti'): (('burgers',
#    'cereals',
#    'frozen vegetables',
#    'whole wheat rice'), 60.0),
#  ('frozen vegetables',
#   'honey',
#   'whole wheat rice'): (('french fries',
#    'mashed potato',
#    'pancakes',
#    'spaghetti'), 41.25),
#  ('frozen vegetables',
#   'honey',
#   'spaghetti',
#   'whole wheat rice'): (('french fries', 'mashed potato', 'pancakes'), 55.0),
#  ('chocolate',
#   'frozen vegetables',
#   'pepper'): (('cereals', 'milk', 'red wine'), 60.0),
#  ('burgers',
#   'chocolate',
#   'frozen vegetables',
#   'spaghetti'): (('cereals', 'cooking oil', 'whole wheat rice'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'frozen vegetables',
#   'milk'): (('burgers', 'cereals', 'spaghetti', 'whole wheat rice'), 60.0),
#  ('cooking oil',
#   'frozen vegetables',
#   'milk',
#   'spaghetti'): (('gluten free bar', 'grated cheese'), 39.0),
#  ('honey',
#   'pepper',
#   'red wine'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'spaghetti',
#    'whole wheat rice'),
#   60.0),
#  ('chocolate', 'pepper', 'red wine'): (('eggs', 'pasta', 'shampoo'), 182.0),
#  ('honey',
#   'red wine',
#   'spaghetti'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'pepper',
#    'whole wheat rice'), 60.0),
#  ('chocolate',
#   'red wine',
#   'spaghetti',
#   'whole wheat rice'): (('cereals',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'pepper'), 60.0),
#  ('honey',
#   'pepper',
#   'red wine',
#   'spaghetti'): (('cereals',
#    'chocolate',
#    'cooking oil',
#    'frozen vegetables',
#    'milk',
#    'whole wheat rice'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'red wine',
#   'whole wheat rice'): (('cereals',
#    'frozen vegetables',
#    'milk',
#    'pepper'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'red wine',
#   'spaghetti'): (('frozen smoothie', 'mineral water'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'milk',
#   'red wine'): (('cereals', 'frozen vegetables', 'pepper'), 60.0),
#  ('chocolate',
#   'cooking oil',
#   'milk',
#   'red wine',
#   'spaghetti'): (('cereals',
#    'frozen vegetables',
#    'pepper',
#    'whole wheat rice'),
#   60.0),
#  ('burgers',
#   'chocolate',
#   'frozen vegetables',
#   'milk',
#   'spaghetti'): (('cereals', 'cooking oil', 'whole wheat rice'), 60.0),
#  ('burgers',
#   'frozen vegetables',
#   'honey',
#   'spaghetti'): (('cereals', 'chocolate', 'whole wheat rice'), 60.0),
#  ('herb & pepper',
#   'mineral water',
#   'muffins'): (('cereals', 'frozen vegetables'), 60.0),
#  ('frozen vegetables',
#   'mineral water',
#   'muffins'): (('cereals', 'herb & pepper'), 60.0),
#  ('cereals', 'frozen vegetables', 'herb & pepper'): (('muffins',),
#   32.94117647058823),
#  ('cereals', 'herb & pepper', 'muffins'): (('frozen vegetables',), 35.0),
#  ('grated cheese', 'muffins'): (('body spray', 'french fries'),
#   45.333333333333336),
#  ('grated cheese', 'mayonnaise'): (('tomato juice',), 40.0),
#  ('mint green tea', 'spaghetti'): (('whole wheat rice',), 35.78947368421053),
#  ('frozen smoothie',
#   'milk',
#   'tomatoes'): (('grated cheese', 'pasta', 'sandwich', 'shrimp'), 45.5),
#  ('frozen smoothie',
#   'shrimp',
#   'tomatoes'): (('grated cheese', 'pasta', 'sandwich'), 182.0),
#  ('milk',
#   'shrimp',
#   'tomatoes'): (('frozen smoothie', 'grated cheese', 'pasta', 'sandwich'),
#   45.5),
#  ('frozen smoothie',
#   'grated cheese',
#   'milk'): (('pasta', 'sandwich', 'shrimp', 'tomatoes'), 45.5),
#  ('grated cheese',
#   'pasta'): (('burgers', 'honey', 'shrimp', 'toothpaste', 'white wine'),
#   143.0),
#  ('frozen smoothie', 'pasta'): (('brownies', 'shrimp'), 73.33333333333333),
#  ('frozen smoothie',
#   'pasta',
#   'tomatoes'): (('grated cheese', 'sandwich', 'shrimp'), 182.0),
#  ('frozen smoothie', 'pasta', 'shrimp'): (('brownies',), 73.33333333333333),
#  ('frozen smoothie',
#   'pasta',
#   'shrimp',
#   'tomatoes'): (('grated cheese', 'sandwich'), 182.0),
#  ('grated cheese',
#   'pasta',
#   'shrimp'): (('burgers', 'honey', 'toothpaste', 'white wine'), 143.0),
#  ('almonds', 'eggs', 'milk', 'mineral water'): (('tomato juice',), 110.0),
#  ('almonds', 'chocolate', 'french fries'): (('body spray',), 82.5),
#  ('almonds',
#   'chocolate',
#   'milk',
#   'mineral water'): (('eggs', 'soup', 'tomato juice'), 33.0),
#  ('chocolate', 'eggs', 'mineral water', 'soup'): (('tomato juice',), 33.0),
#  ('chocolate',
#   'eggs',
#   'milk',
#   'mineral water',
#   'soup'): (('almonds', 'tomato juice'), 33.0),
#  ('eggs', 'mineral water', 'soup'): (('frozen smoothie', 'spaghetti'), 30.0),
#  ('frozen vegetables',
#   'herb & pepper',
#   'olive oil'): (('mint', 'spaghetti', 'tomatoes'), 42.0),
#  ('herb & pepper', 'milk', 'olive oil'): (('pancakes', 'spaghetti'), 55.0),
#  ('herb & pepper', 'mineral water', 'soup'): (('almonds', 'milk', 'olive oil'),
#   143.0),
#  ('herb & pepper', 'milk', 'soup'): (('almonds',), 143.0),
#  ('almonds', 'chocolate', 'white wine'): (('eggs',), 30.333333333333332),
#  ('frozen vegetables', 'milk', 'mineral water', 'soup'): (('almonds',), 71.5),
#  ('cooking oil', 'frozen vegetables', 'gums'): (('gluten free bar',), 39.0),
#  ('burgers',
#   'olive oil',
#   'turkey'): (('chocolate', 'cooking oil', 'corn', 'eggs'), 45.5),
#  ('eggs', 'olive oil', 'turkey'): (('cooking oil', 'corn'), 182.0),
#  ('burgers', 'chocolate', 'eggs', 'turkey'): (('cottage cheese', 'hot dogs'),
#   110.0),
#  ('burgers', 'chocolate', 'eggs', 'olive oil'): (('corn',), 45.5),
#  ('chocolate', 'cooking oil', 'eggs', 'turkey'): (('corn', 'olive oil'),
#   182.0),
#  ('corn', 'herb & pepper'): (('grated cheese',), 32.94117647058823),
#  ('eggs', 'olive oil', 'soup'): (('avocado', 'bug spray', 'pasta', 'shrimp'),
#   41.25),
#  ('chocolate', 'pepper', 'shrimp'): (('eggs', 'pasta', 'red wine', 'shampoo'),
#   45.5),
#  ('eggs', 'pepper', 'red wine'): (('chocolate', 'pasta', 'shampoo'), 182.0),
#  ('eggs', 'red wine', 'shrimp'): (('chocolate', 'pasta', 'pepper', 'shampoo'),
#   45.5),
#  ('pasta', 'pepper', 'shrimp'): (('chocolate', 'eggs', 'red wine', 'shampoo'),
#   45.5),
#  ('eggs', 'pasta', 'pepper', 'shrimp'): (('chocolate', 'red wine', 'shampoo'),
#   45.5),
#  ('avocado', 'eggs', 'olive oil'): (('brownies', 'french fries'), 60.0),
#  ('avocado',
#   'eggs',
#   'milk',
#   'soup'): (('bug spray', 'mineral water', 'pasta', 'shrimp'), 82.5),
#  ('avocado',
#   'mineral water',
#   'soup'): (('bug spray', 'eggs', 'pasta', 'shrimp'), 82.5),
#  ('avocado',
#   'eggs',
#   'mineral water',
#   'olive oil'): (('bug spray', 'pasta', 'shrimp'), 82.5),
#  ('avocado',
#   'eggs',
#   'milk',
#   'mineral water'): (('brownies', 'chocolate', 'french fries'), 40.0),
#  ('avocado', 'eggs', 'milk', 'olive oil'): (('bug spray', 'mineral water'),
#   82.5),
#  ('avocado', 'milk', 'mineral water', 'olive oil'): (('brownies', 'chocolate'),
#   40.0),
#  ('eggs',
#   'milk',
#   'mineral water',
#   'olive oil'): (('brownies', 'chocolate', 'spaghetti'), 60.0),
#  ('avocado', 'eggs', 'milk', 'mineral water', 'olive oil'): (('bug spray',),
#   82.5),
#  ('avocado',
#   'olive oil',
#   'shrimp'): (('bug spray', 'eggs', 'mineral water', 'pasta'), 82.5),
#  ('eggs',
#   'mineral water',
#   'olive oil',
#   'shrimp'): (('avocado', 'bug spray', 'pasta'), 55.0),
#  ('eggs',
#   'milk',
#   'mineral water',
#   'shrimp'): (('avocado', 'bug spray', 'pasta', 'soup'), 41.25),
#  ('avocado',
#   'mineral water',
#   'olive oil',
#   'shrimp'): (('bug spray', 'eggs', 'pasta'), 82.5),
#  ('avocado',
#   'milk',
#   'mineral water',
#   'shrimp'): (('bug spray', 'eggs', 'pasta', 'soup'), 82.5),
#  ('eggs',
#   'milk',
#   'mineral water',
#   'shrimp',
#   'soup'): (('avocado', 'bug spray', 'pasta'), 82.5),
#  ('avocado',
#   'pasta'): (('burgers',
#    'grated cheese',
#    'honey',
#    'shrimp',
#    'toothpaste',
#    'white wine'),
#   39.0),
#  ('pasta',
#   'soup'): (('avocado', 'bug spray', 'eggs', 'mineral water', 'shrimp'), 82.5),
#  ('pasta',
#   'shrimp',
#   'soup'): (('avocado', 'bug spray', 'eggs', 'mineral water'), 82.5),
#  ('avocado',
#   'pasta',
#   'shrimp'): (('burgers',
#    'grated cheese',
#    'honey',
#    'toothpaste',
#    'white wine'),
#   39.0),
#  ('eggs',
#   'milk',
#   'pasta'): (('avocado',
#    'bug spray',
#    'mineral water',
#    'shrimp',
#    'soup'), 82.5),
#  ('eggs',
#   'milk',
#   'pasta',
#   'shrimp'): (('avocado', 'bug spray', 'mineral water', 'soup'), 82.5),
#  ('eggs',
#   'olive oil',
#   'pasta',
#   'shrimp'): (('avocado', 'bug spray', 'mineral water'), 55.0),
#  ('mineral water',
#   'olive oil',
#   'pasta'): (('avocado', 'bug spray', 'eggs', 'shrimp'), 55.0),
#  ('eggs',
#   'mineral water',
#   'olive oil',
#   'pasta'): (('avocado', 'bug spray', 'shrimp'), 55.0),
#  ('eggs',
#   'milk',
#   'mineral water',
#   'pasta'): (('avocado', 'bug spray', 'shrimp', 'soup'), 82.5),
#  ('mineral water', 'olive oil', 'shrimp', 'soup'): (('champagne', 'chocolate'),
#   55.0),
#  ('eggs',
#   'mineral water',
#   'olive oil',
#   'pasta',
#   'shrimp'): (('avocado', 'bug spray'), 55.0),
#  ('eggs',
#   'milk',
#   'mineral water',
#   'pasta',
#   'shrimp'): (('avocado', 'bug spray', 'soup'), 82.5),
#  ('energy bar', 'french fries', 'shrimp'): (('body spray', 'burgers'), 82.5),
#  ('french fries', 'shrimp', 'tomatoes'): (('body spray',), 82.5),
#  ('frozen vegetables',
#   'tomato juice',
#   'tomatoes'): (('french fries', 'fresh bread', 'spaghetti'), 42.0),
#  ('honey', 'soup'): (('brownies', 'cake', 'ground beef', 'salt'), 60.0),
#  ('eggs', 'herb & pepper', 'tomatoes'): (('cooking oil',), 60.0),
#  ('french fries', 'frozen vegetables', 'tomatoes'): (('escalope',),
#   151.66666666666666),
#  ('french fries',
#   'frozen vegetables',
#   'spaghetti',
#   'tomatoes'): (('escalope',), 52.5),
#  ('mineral water', 'spaghetti', 'tomato juice'): (('low fat yogurt',), 60.0),
#  ('chocolate', 'eggs', 'tomatoes'): (('tomato juice',), 33.0),
#  ('cake', 'spaghetti', 'tomatoes'): (('eggs', 'tomato juice'), 42.0),
#  ('frozen smoothie',
#   'olive oil',
#   'tomatoes'): (('frozen vegetables', 'green tea', 'mint', 'spaghetti'), 42.0),
#  ('frozen smoothie',
#   'olive oil',
#   'spaghetti',
#   'tomatoes'): (('frozen vegetables', 'green tea', 'mint'), 42.0),
#  ('cake', 'spaghetti', 'whole wheat rice'): (('chocolate', 'protein bar'),
#   110.0),
#  ('french fries',
#   'mineral water',
#   'olive oil'): (('brownies', 'chocolate', 'eggs'), 60.0),
#  ('escalope', 'french fries', 'tomatoes'): (('frozen vegetables',),
#   30.333333333333332),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'tomatoes'): (('green tea', 'mint', 'olive oil', 'spaghetti'), 42.0),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'green tea',
#   'tomatoes'): (('mint', 'olive oil', 'spaghetti'), 42.0),
#  ('frozen vegetables',
#   'herb & pepper',
#   'tomatoes'): (('mint', 'olive oil', 'spaghetti'), 42.0),
#  ('green tea', 'spaghetti', 'tomatoes'): (('mint',), 42.0),
#  ('frozen smoothie',
#   'green tea',
#   'spaghetti'): (('frozen vegetables', 'mint', 'olive oil', 'tomatoes'), 42.0),
#  ('cake', 'frozen vegetables', 'tomatoes'): (('green tea', 'mint'), 33.0),
#  ('cake', 'green tea', 'tomatoes'): (('brownies', 'eggs', 'tomato juice'),
#   42.0),
#  ('brownies', 'cake', 'tomatoes'): (('eggs', 'tomato juice'), 42.0),
#  ('cake', 'eggs', 'tomatoes'): (('tomato juice',), 42.0),
#  ('brownies',
#   'cake',
#   'eggs'): (('mineral water', 'pasta', 'shrimp', 'tomato juice'), 33.0),
#  ('chocolate', 'milk', 'rice'): (('brownies',), 60.0),
#  ('avocado', 'chocolate', 'rice'): (('brownies',), 60.0),
#  ('chocolate', 'green tea', 'rice'): (('ground beef', 'toothpaste'), 60.0),
#  ('chocolate', 'fresh bread', 'rice'): (('magazines',), 33.0),
#  ('avocado',
#   'chicken'): (('cooking oil', 'frozen vegetables', 'mashed potato', 'turkey'),
#   110.0),
#  ('chicken', 'ground beef', 'milk'): (('rice',), 280.0),
#  ('chicken', 'ground beef', 'rice'): (('milk',), 32.94117647058823),
#  ('ground beef', 'milk', 'rice'): (('chicken',), 35.0),
#  ('brownies',
#   'chocolate',
#   'pancakes'): (('eggs', 'french fries', 'light mayo', 'spaghetti'), 33.0),
#  ('brownies',
#   'pancakes',
#   'spaghetti'): (('chocolate', 'eggs', 'french fries', 'light mayo'), 33.0),
#  ('brownies',
#   'chocolate',
#   'pancakes',
#   'spaghetti'): (('eggs', 'french fries', 'light mayo'), 33.0),
#  ('chocolate',
#   'pancakes',
#   'shrimp',
#   'spaghetti'): (('escalope', 'french fries', 'melons'), 33.0),
#  ('brownies',
#   'chocolate',
#   'french fries',
#   'pancakes'): (('eggs', 'light mayo', 'spaghetti'), 33.0),
#  ('chocolate', 'french fries', 'pancakes', 'shrimp'): (('escalope', 'melons'),
#   110.0),
#  ('brownies', 'french fries', 'pancakes'): (('eggs', 'light mayo'), 55.0),
#  ('brownies',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('chocolate', 'eggs', 'light mayo'), 33.0),
#  ('brownies',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('eggs', 'light mayo'), 33.0),
#  ('chocolate',
#   'french fries',
#   'pancakes',
#   'shrimp',
#   'spaghetti'): (('escalope', 'melons'), 33.0),
#  ('escalope',
#   'shrimp',
#   'spaghetti'): (('chocolate', 'french fries', 'melons', 'pancakes'), 33.0),
#  ('escalope', 'french fries', 'shrimp'): (('melons', 'pancakes'), 110.0),
#  ('chocolate', 'escalope', 'pancakes'): (('mineral water', 'tomato juice'),
#   45.5),
#  ('escalope',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('chocolate', 'melons', 'shrimp'), 33.0),
#  ('cookies', 'french fries', 'pancakes'): (('brownies', 'escalope', 'melons'),
#   110.0),
#  ('cookies',
#   'escalope',
#   'french fries',
#   'shrimp'): (('brownies', 'melons', 'pancakes', 'spaghetti'), 110.0),
#  ('milk',
#   'soup',
#   'whole wheat rice'): (('chocolate',
#    'eggs',
#    'escalope',
#    'frozen vegetables',
#    'melons'),
#   39.0),
#  ('chocolate',
#   'milk',
#   'soup',
#   'whole wheat rice'): (('eggs',
#    'escalope',
#    'frozen vegetables',
#    'melons'), 39.0),
#  ('chocolate',
#   'frozen vegetables',
#   'milk',
#   'soup'): (('eggs', 'escalope', 'melons'), 39.0),
#  ('chocolate',
#   'eggs',
#   'frozen vegetables',
#   'whole wheat rice'): (('escalope', 'melons'), 143.0),
#  ('chocolate',
#   'eggs',
#   'frozen vegetables',
#   'milk',
#   'whole wheat rice'): (('escalope', 'melons'), 143.0),
#  ('chocolate',
#   'escalope',
#   'milk',
#   'whole wheat rice'): (('eggs', 'frozen vegetables', 'melons'), 143.0),
#  ('chocolate', 'escalope', 'whole wheat rice'): (('cookies',), 55.0),
#  ('escalope',
#   'frozen vegetables',
#   'milk',
#   'whole wheat rice'): (('chocolate', 'eggs', 'melons'), 143.0),
#  ('chocolate',
#   'escalope',
#   'frozen vegetables',
#   'whole wheat rice'): (('eggs', 'melons'), 143.0),
#  ('chocolate',
#   'escalope',
#   'frozen vegetables',
#   'milk',
#   'whole wheat rice'): (('eggs', 'melons'), 143.0),
#  ('eggs',
#   'escalope',
#   'milk',
#   'whole wheat rice'): (('chocolate', 'frozen vegetables', 'melons'), 143.0),
#  ('eggs',
#   'escalope',
#   'frozen vegetables',
#   'milk'): (('chocolate', 'melons', 'soup'), 39.0),
#  ('eggs',
#   'escalope',
#   'frozen vegetables',
#   'milk',
#   'whole wheat rice'): (('chocolate', 'melons'), 143.0),
#  ('chocolate',
#   'eggs',
#   'escalope',
#   'milk'): (('frozen vegetables', 'melons', 'soup'), 39.0),
#  ('chocolate',
#   'eggs',
#   'escalope',
#   'milk',
#   'whole wheat rice'): (('frozen vegetables', 'melons'), 143.0),
#  ('chocolate', 'eggs', 'escalope', 'whole wheat rice'): (('melons',),
#   95.33333333333333),
#  ('chocolate', 'eggs', 'escalope', 'frozen vegetables'): (('melons',), 143.0),
#  ('chocolate',
#   'eggs',
#   'escalope',
#   'frozen vegetables',
#   'milk'): (('melons', 'soup'), 39.0),
#  ('chocolate',
#   'eggs',
#   'escalope',
#   'frozen vegetables',
#   'milk',
#   'whole wheat rice'): (('melons',), 143.0),
#  ('burgers', 'ground beef', 'spaghetti'): (('escalope', 'melons'), 52.5),
#  ('burgers', 'melons', 'mineral water'): (('escalope',), 30.333333333333332),
#  ('burgers', 'escalope', 'mineral water'): (('melons',), 227.5),
#  ('burgers',
#   'escalope',
#   'mineral water',
#   'spaghetti'): (('ground beef', 'melons'), 52.5),
#  ('escalope', 'ground beef', 'melons'): (('burgers', 'mineral water'),
#   30.333333333333332),
#  ('burgers', 'escalope', 'ground beef', 'melons'): (('mineral water',),
#   30.333333333333332),
#  ('escalope', 'ground beef', 'melons', 'mineral water'): (('burgers',),
#   30.333333333333332),
#  ('burgers', 'melons', 'spaghetti'): (('escalope',), 30.333333333333332),
#  ('chocolate',
#   'energy bar',
#   'milk'): (('body spray', 'burgers', 'french fries', 'shrimp'), 82.5),
#  ('burgers',
#   'chocolate',
#   'energy bar',
#   'milk'): (('body spray', 'french fries', 'shrimp'), 82.5),
#  ('chicken', 'french fries', 'milk'): (('eggs', 'fresh bread'), 40.0),
#  ('chicken',
#   'chocolate',
#   'french fries',
#   'shrimp'): (('body spray', 'burgers'), 82.5),
#  ('body spray',
#   'chicken',
#   'soup'): (('eggs', 'energy bar', 'french fries', 'strawberries'), 39.0),
#  ('eggs', 'energy bar', 'soup'): (('strawberries',), 143.0),
#  ('body spray',
#   'french fries',
#   'soup'): (('chicken', 'eggs', 'energy bar', 'strawberries'), 39.0),
#  ('chicken', 'energy bar', 'french fries'): (('eggs', 'soup', 'strawberries'),
#   39.0),
#  ('body spray', 'champagne', 'eggs'): (('french fries',), 35.0),
#  ('escalope',
#   'grated cheese',
#   'whole wheat rice'): (('cottage cheese', 'french fries'), 143.0),
#  ('grated cheese', 'olive oil', 'spaghetti'): (('mint',), 39.0),
#  ('avocado',
#   'burgers',
#   'grated cheese'): (('honey', 'pasta', 'shrimp', 'toothpaste', 'white wine'),
#   39.0),
#  ('honey', 'pasta'): (('burgers', 'shrimp', 'toothpaste', 'white wine'),
#   143.0),
#  ('grated cheese',
#   'honey',
#   'shrimp'): (('burgers', 'pasta', 'toothpaste', 'white wine'), 143.0),
#  ('avocado',
#   'honey',
#   'shrimp'): (('burgers',
#    'grated cheese',
#    'pasta',
#    'toothpaste',
#    'white wine'),
#   39.0),
#  ('honey', 'pasta', 'shrimp'): (('burgers', 'toothpaste', 'white wine'),
#   143.0),
#  ('burgers',
#   'grated cheese',
#   'honey'): (('pasta', 'shrimp', 'toothpaste', 'white wine'), 143.0),
#  ('cake', 'eggs', 'toothpaste'): (('green tea',), 32.94117647058823),
#  ('cake', 'green tea', 'toothpaste'): (('eggs',), 32.94117647058823),
#  ('eggs', 'mineral water', 'olive oil', 'spaghetti'): (('brownies',), 60.0),
#  ('burgers',
#   'eggs',
#   'pasta',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'mineral water', 'salt'),
#   42.0),
#  ('burgers',
#   'mineral water',
#   'olive oil',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'pasta', 'salt'), 42.0),
#  ('burgers',
#   'mineral water',
#   'pasta',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'salt'), 42.0),
#  ('burgers',
#   'eggs',
#   'mineral water',
#   'pasta',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'salt'), 42.0),
#  ('eggs',
#   'energy bar',
#   'olive oil'): (('burgers',
#    'herb & pepper',
#    'mineral water',
#    'salt',
#    'spaghetti'),
#   42.0),
#  ('eggs',
#   'energy bar',
#   'mineral water',
#   'spaghetti'): (('burgers', 'herb & pepper', 'pasta', 'salt'), 42.0),
#  ('burgers',
#   'eggs',
#   'energy bar',
#   'olive oil'): (('herb & pepper', 'mineral water', 'salt', 'spaghetti'),
#   42.0),
#  ('burgers',
#   'mineral water',
#   'pasta',
#   'shrimp'): (('eggs', 'energy bar', 'herb & pepper', 'salt', 'spaghetti'),
#   42.0),
#  ('burgers',
#   'eggs',
#   'mineral water',
#   'pasta',
#   'shrimp'): (('energy bar', 'herb & pepper', 'salt', 'spaghetti'), 42.0),
#  ('eggs',
#   'energy bar',
#   'herb & pepper'): (('burgers',
#    'mineral water',
#    'pasta',
#    'salt',
#    'spaghetti'),
#   42.0),
#  ('eggs',
#   'herb & pepper',
#   'mineral water',
#   'shrimp'): (('burgers', 'energy bar', 'pasta', 'salt', 'spaghetti'), 42.0),
#  ('herb & pepper', 'pasta', 'spaghetti'): (('burgers', 'energy bar', 'salt'),
#   42.0),
#  ('herb & pepper',
#   'pasta',
#   'shrimp',
#   'spaghetti'): (('burgers',
#    'eggs',
#    'energy bar',
#    'mineral water',
#    'salt'), 42.0),
#  ('burgers',
#   'eggs',
#   'energy bar',
#   'herb & pepper'): (('mineral water', 'pasta', 'salt', 'spaghetti'), 42.0),
#  ('burgers',
#   'eggs',
#   'mineral water',
#   'shrimp',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'pasta', 'salt'), 42.0),
#  ('burgers',
#   'mineral water',
#   'pasta',
#   'shrimp',
#   'spaghetti'): (('eggs', 'energy bar', 'herb & pepper', 'salt'), 42.0),
#  ('burgers',
#   'eggs',
#   'mineral water',
#   'pasta',
#   'shrimp',
#   'spaghetti'): (('energy bar', 'herb & pepper', 'salt'), 42.0),
#  ('brownies', 'honey', 'turkey'): (('cake', 'ground beef', 'salt', 'soup'),
#   60.0),
#  ('brownies', 'ground beef'): (('cake', 'salt', 'soup'), 60.0),
#  ('ground beef', 'honey', 'turkey'): (('brownies', 'cake', 'salt', 'soup'),
#   60.0),
#  ('brownies', 'honey', 'milk'): (('ground beef', 'salt', 'soup'), 60.0),
#  ('brownies', 'cake', 'milk'): (('ground beef', 'salt', 'soup'), 60.0),
#  ('brownies', 'milk', 'turkey'): (('cake', 'salt'), 60.0),
#  ('brownies', 'cake', 'milk', 'turkey'): (('salt',), 60.0),
#  ('cake', 'ground beef', 'honey'): (('brownies', 'salt', 'soup'), 60.0),
#  ('energy drink', 'mineral water', 'spaghetti'): (('salt', 'soup', 'turkey'),
#   39.0),
#  ('energy drink',
#   'spaghetti',
#   'turkey'): (('cake', 'eggs', 'gluten free bar', 'pancakes'), 82.5),
#  ('energy drink', 'soup', 'spaghetti'): (('mineral water', 'salt', 'turkey'),
#   39.0),
#  ('energy drink', 'mineral water', 'soup', 'spaghetti'): (('salt', 'turkey'),
#   39.0),
#  ('mineral water', 'soup', 'spaghetti', 'turkey'): (('salt',), 39.0),
#  ('chocolate', 'cooking oil', 'soup'): (('champagne', 'salt'), 182.0),
#  ('burgers', 'ground beef', 'pancakes'): (('salt',), 68.0),
#  ('burgers',
#   'spaghetti',
#   'turkey'): (('cake', 'eggs', 'energy drink', 'gluten free bar'), 82.5),
#  ('cottage cheese',
#   'energy drink'): (('cake',
#    'eggs',
#    'gluten free bar',
#    'pancakes',
#    'spaghetti',
#    'turkey'),
#   82.5),
#  ('energy drink', 'pancakes', 'spaghetti'): (('milk', 'white wine'), 45.5),
#  ('cake',
#   'pancakes',
#   'spaghetti',
#   'turkey'): (('eggs', 'energy drink', 'gluten free bar'), 82.5),
#  ('burgers', 'cake', 'eggs', 'turkey'): (('light mayo',), 73.33333333333333),
#  ('eggs',
#   'energy drink',
#   'pancakes'): (('cake', 'gluten free bar', 'spaghetti'), 82.5),
#  ('burgers',
#   'cake',
#   'eggs',
#   'pancakes',
#   'turkey'): (('energy drink', 'gluten free bar'), 82.5),
#  ('burgers', 'eggs', 'pancakes', 'spaghetti'): (('low fat yogurt', 'milk'),
#   30.333333333333332),
#  ('cake', 'eggs', 'pancakes', 'spaghetti'): (('gluten free bar',), 82.5),
#  ('cake',
#   'eggs',
#   'pancakes',
#   'spaghetti',
#   'turkey'): (('energy drink', 'gluten free bar'), 82.5),
#  ('honey',
#   'mineral water',
#   'salmon'): (('gluten free bar', 'green tea', 'mushroom cream sauce'), 110.0),
#  ('green tea',
#   'honey',
#   'mineral water',
#   'salmon'): (('gluten free bar', 'mushroom cream sauce'), 110.0),
#  ('mineral water', 'mushroom cream sauce', 'salmon'): (('gluten free bar',),
#   110.0),
#  ('cooking oil',
#   'grated cheese',
#   'spaghetti'): (('frozen vegetables', 'gluten free bar', 'milk'), 39.0),
#  ('avocado', 'frozen smoothie', 'salmon'): (('hot dogs', 'mineral water'),
#   33.0),
#  ('avocado', 'mineral water', 'muffins'): (('cake', 'milk'), 60.0),
#  ('avocado', 'milk', 'mineral water', 'muffins'): (('cake',), 60.0),
#  ('avocado',
#   'chocolate',
#   'olive oil'): (('brownies', 'french fries', 'mineral water'), 60.0),
#  ('avocado',
#   'chocolate',
#   'mineral water',
#   'olive oil'): (('brownies', 'french fries'), 60.0),
#  ('avocado',
#   'chocolate',
#   'milk',
#   'mineral water'): (('brownies', 'french fries'), 40.0),
#  ('avocado', 'chocolate', 'milk', 'olive oil'): (('brownies', 'mineral water'),
#   60.0),
#  ('avocado',
#   'chocolate',
#   'milk',
#   'mineral water',
#   'olive oil'): (('brownies',), 60.0),
#  ('avocado',
#   'chocolate',
#   'french fries',
#   'milk'): (('brownies', 'mineral water'), 60.0),
#  ('chocolate',
#   'french fries',
#   'mineral water',
#   'olive oil'): (('brownies', 'eggs'), 60.0),
#  ('chocolate',
#   'eggs',
#   'french fries',
#   'milk',
#   'mineral water'): (('brownies',), 40.0),
#  ('frozen vegetables',
#   'ground beef',
#   'honey'): (('french fries',
#    'mashed potato',
#    'pancakes',
#    'spaghetti',
#    'whole wheat rice'),
#   55.0),
#  ('ground beef',
#   'honey',
#   'spaghetti'): (('french fries',
#    'frozen vegetables',
#    'mashed potato',
#    'pancakes',
#    'whole wheat rice'), 82.5),
#  ('frozen smoothie',
#   'pancakes',
#   'whole wheat rice'): (('french fries',
#    'frozen vegetables',
#    'mashed potato',
#    'spaghetti'), 82.5),
#  ('frozen smoothie',
#   'honey',
#   'whole wheat rice'): (('french fries',
#    'frozen vegetables',
#    'mashed potato',
#    'pancakes'), 82.5),
#  ('frozen smoothie',
#   'ground beef',
#   'pancakes',
#   'spaghetti'): (('frozen vegetables', 'mashed potato'), 82.5),
#  ('frozen vegetables',
#   'honey',
#   'pancakes',
#   'spaghetti'): (('french fries', 'mashed potato', 'whole wheat rice'), 82.5),
#  ('french fries',
#   'frozen smoothie',
#   'ground beef'): (('frozen vegetables', 'mashed potato', 'spaghetti'), 82.5),
#  ('french fries',
#   'frozen smoothie',
#   'pancakes'): (('low fat yogurt', 'mineral water', 'white wine'),
#   30.333333333333332),
#  ('french fries',
#   'pancakes',
#   'whole wheat rice'): (('frozen vegetables',
#    'mashed potato',
#    'spaghetti'), 82.5),
#  ('french fries', 'spaghetti', 'whole wheat rice'): (('chocolate', 'cookies'),
#   110.0),
#  ('frozen smoothie',
#   'honey',
#   'spaghetti',
#   'whole wheat rice'): (('french fries', 'mashed potato', 'pancakes'), 82.5),
#  ('french fries',
#   'frozen smoothie',
#   'frozen vegetables',
#   'spaghetti'): (('mashed potato', 'pancakes', 'whole wheat rice'), 82.5),
#  ('french fries',
#   'frozen vegetables',
#   'ground beef',
#   'honey'): (('mashed potato', 'pancakes', 'spaghetti', 'whole wheat rice'),
#   82.5),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'honey',
#   'whole wheat rice'): (('french fries', 'mashed potato', 'pancakes'), 82.5),
#  ('french fries',
#   'frozen vegetables',
#   'pancakes',
#   'spaghetti'): (('mashed potato',), 55.0),
#  ('avocado',
#   'cooking oil'): (('chicken', 'frozen vegetables', 'mashed potato', 'turkey'),
#   110.0),
#  ('cooking oil', 'frozen vegetables', 'turkey'): (('chicken', 'mashed potato'),
#   110.0),
#  ('cake',
#   'frozen vegetables',
#   'turkey'): (('avocado', 'chicken', 'cooking oil', 'mashed potato'), 33.0),
#  ('cake',
#   'chicken',
#   'turkey'): (('avocado', 'cooking oil', 'frozen vegetables', 'mashed potato'),
#   33.0),
#  ('cake',
#   'chicken',
#   'cooking oil'): (('avocado',
#    'frozen vegetables',
#    'mashed potato',
#    'turkey'), 33.0),
#  ('cake', 'chicken', 'frozen vegetables'): (('mashed potato', 'turkey'),
#   73.33333333333333),
#  ('chicken', 'frozen vegetables', 'turkey'): (('mashed potato',), 110.0),
#  ('salmon',
#   'shallot'): (('frozen smoothie',
#    'frozen vegetables',
#    'magazines',
#    'pasta',
#    'spaghetti'), 42.0),
#  ('light mayo',
#   'pasta'): (('frozen smoothie',
#    'frozen vegetables',
#    'magazines',
#    'salmon',
#    'spaghetti'), 42.0),
#  ('light mayo',
#   'pasta',
#   'shrimp'): (('frozen smoothie',
#    'frozen vegetables',
#    'magazines',
#    'salmon',
#    'spaghetti'), 42.0),
#  ('shallot',
#   'spaghetti'): (('frozen smoothie',
#    'frozen vegetables',
#    'magazines',
#    'pasta',
#    'salmon'), 42.0),
#  ('frozen smoothie',
#   'salmon',
#   'shrimp',
#   'spaghetti'): (('frozen vegetables',
#    'light mayo',
#    'magazines',
#    'pasta'), 42.0),
#  ('frozen vegetables',
#   'light mayo',
#   'spaghetti'): (('frozen smoothie', 'magazines', 'pasta', 'salmon'), 42.0),
#  ('frozen vegetables',
#   'pasta',
#   'spaghetti'): (('frozen smoothie', 'magazines', 'salmon'), 42.0),
#  ('frozen vegetables',
#   'pasta',
#   'shrimp',
#   'spaghetti'): (('frozen smoothie', 'light mayo', 'magazines', 'salmon'),
#   42.0),
#  ('olive oil',
#   'red wine'): (('chocolate', 'cookies', 'french fries', 'magazines'), 82.5),
#  ('chocolate', 'cookies', 'olive oil'): (('french fries', 'magazines'), 82.5),
#  ('cookies', 'french fries', 'fresh bread'): (('chocolate', 'magazines'),
#   82.5),
#  ('french fries', 'fresh bread', 'olive oil'): (('cookies', 'magazines'),
#   82.5),
#  ('ground beef', 'magazines', 'salmon'): (('chocolate',), 30.333333333333332),
#  ('ground beef',
#   'muffins',
#   'salmon'): (('chocolate', 'frozen vegetables', 'magazines'), 52.5),
#  ('ground beef', 'magazines', 'muffins'): (('chocolate',), 30.333333333333332),
#  ('chocolate', 'frozen vegetables', 'muffins'): (('ground beef', 'magazines'),
#   227.5),
#  ('chocolate', 'frozen vegetables', 'magazines'): (('ground beef', 'muffins'),
#   30.333333333333332),
#  ('chocolate', 'frozen vegetables', 'ground beef', 'magazines'): (('muffins',),
#   30.333333333333332),
#  ('chocolate', 'frozen vegetables', 'magazines', 'muffins'): (('ground beef',),
#   30.333333333333332),
#  ('chocolate',
#   'olive oil',
#   'salmon'): (('champagne', 'mineral water', 'shrimp', 'soup'), 82.5),
#  ('eggs', 'frozen smoothie', 'turkey'): (('low fat yogurt',),
#   30.333333333333332),
#  ('cooking oil',
#   'mineral water',
#   'pancakes',
#   'whole wheat rice'): (('chocolate', 'eggs', 'zucchini'), 33.0),
#  ('burgers',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'turkey'): (('cake', 'eggs', 'light mayo'), 33.0),
#  ('burgers', 'cake', 'milk', 'turkey'): (('eggs', 'ground beef', 'light mayo'),
#   110.0),
#  ('burgers', 'cake', 'ground beef', 'milk', 'turkey'): (('eggs', 'light mayo'),
#   110.0),
#  ('cake',
#   'eggs',
#   'milk',
#   'mineral water',
#   'turkey'): (('burgers', 'ground beef', 'light mayo'), 33.0),
#  ('eggs',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'turkey'): (('burgers', 'cake', 'light mayo'), 33.0),
#  ('burgers',
#   'eggs',
#   'milk',
#   'mineral water',
#   'turkey'): (('cake', 'ground beef', 'light mayo'), 33.0),
#  ('burgers', 'eggs', 'ground beef', 'milk', 'turkey'): (('cake', 'light mayo'),
#   110.0),
#  ('burgers',
#   'eggs',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'turkey'): (('cake', 'light mayo'), 33.0),
#  ('burgers', 'cake', 'eggs', 'milk'): (('light mayo', 'mineral water'), 33.0),
#  ('burgers', 'cake', 'eggs', 'mineral water'): (('light mayo',), 110.0),
#  ('ground beef',
#   'milk',
#   'mineral water',
#   'turkey'): (('olive oil', 'spaghetti'), 40.0),
#  ('eggs', 'ground beef', 'hot dogs'): (('chocolate', 'cottage cheese'), 33.0),
#  ('chocolate', 'hot dogs', 'turkey'): (('burgers', 'cottage cheese'), 110.0),
#  ('chocolate', 'eggs', 'hot dogs'): (('cottage cheese',), 33.0),
#  ('chocolate', 'eggs', 'ground beef', 'hot dogs'): (('cottage cheese',), 33.0),
#  ('escalope', 'spaghetti', 'yogurt cake'): (('turkey',), 30.333333333333332),
#  ('spaghetti', 'turkey', 'yogurt cake'): (('escalope',), 30.333333333333332),
#  ('chocolate', 'milk', 'spaghetti', 'turkey'): (('whole wheat rice',),
#   31.11111111111111),
#  ('eggs', 'french fries', 'zucchini'): (('turkey',), 30.333333333333332),
#  ('cake', 'eggs', 'french fries', 'turkey'): (('green tea', 'tomato juice'),
#   42.0),
#  ('chocolate', 'eggs', 'turkey'): (('tomato juice',), 32.94117647058823),
#  ('french fries', 'milk', 'pasta'): (('green tea', 'white wine'), 39.0),
#  ('french fries', 'milk', 'pasta', 'shrimp'): (('white wine',), 143.0),
#  ('chicken',
#   'mineral water',
#   'salmon',
#   'shrimp'): (('eggs', 'frozen smoothie', 'strawberries'), 82.5),
#  ('eggs',
#   'french fries',
#   'milk',
#   'mineral water',
#   'shrimp'): (('chocolate', 'fresh bread'), 39.0),
#  ('chocolate',
#   'eggs',
#   'milk',
#   'mineral water',
#   'shrimp'): (('french fries', 'fresh bread'), 39.0),
#  ('chocolate',
#   'french fries',
#   'milk',
#   'mineral water',
#   'shrimp'): (('eggs', 'fresh bread'), 39.0),
#  ('chocolate',
#   'eggs',
#   'french fries',
#   'milk',
#   'mineral water',
#   'shrimp'): (('fresh bread',), 39.0),
#  ('burgers',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'spaghetti'): (('french fries', 'low fat yogurt'), 30.333333333333332),
#  ('eggs', 'milk', 'pancakes', 'spaghetti'): (('burgers', 'low fat yogurt'),
#   45.5),
#  ('burgers',
#   'french fries',
#   'milk',
#   'pancakes'): (('low fat yogurt', 'spaghetti'), 45.5),
#  ('burgers',
#   'french fries',
#   'mineral water',
#   'pancakes'): (('low fat yogurt', 'milk', 'spaghetti'), 45.5),
#  ('burgers',
#   'french fries',
#   'milk',
#   'mineral water',
#   'pancakes'): (('low fat yogurt', 'spaghetti'), 45.5),
#  ('burgers',
#   'french fries',
#   'mineral water',
#   'pancakes',
#   'spaghetti'): (('low fat yogurt', 'milk'), 45.5),
#  ('burgers',
#   'eggs',
#   'mineral water',
#   'spaghetti'): (('french fries', 'low fat yogurt'), 30.333333333333332),
#  ('frozen vegetables', 'salmon', 'shrimp'): (('champagne', 'olive oil'), 55.0),
#  ('mineral water',
#   'olive oil',
#   'salmon',
#   'shrimp'): (('champagne', 'chocolate', 'soup'), 55.0),
#  ('chocolate', 'mineral water', 'shrimp', 'soup'): (('champagne', 'olive oil'),
#   82.5),
#  ('chocolate', 'mineral water', 'olive oil', 'shrimp'): (('champagne',), 82.5),
#  ('chicken', 'milk', 'mineral water', 'spaghetti'): (('cake',), 60.0),
#  ('chicken', 'mineral water', 'olive oil', 'spaghetti'): (('cake', 'pancakes'),
#   40.0),
#  ('milk',
#   'mineral water',
#   'shrimp',
#   'spaghetti'): (('chicken', 'oil', 'olive oil'), 33.0),
#  ('chicken',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'spaghetti'): (('cake', 'oil'), 82.5),
#  ('frozen smoothie',
#   'mineral water',
#   'salmon',
#   'shrimp'): (('chicken', 'eggs', 'strawberries'), 55.0),
#  ('chicken',
#   'frozen smoothie',
#   'shrimp'): (('eggs', 'mineral water', 'strawberries'), 82.5),
#  ('cake', 'eggs', 'mineral water', 'shrimp'): (('tomato juice',), 55.0),
#  ('chicken', 'eggs', 'mineral water', 'shrimp'): (('strawberries',), 82.5),
#  ('french fries', 'green tea', 'shrimp'): (('white wine',), 57.0),
#  ('chocolate', 'french fries', 'green tea', 'spaghetti'): (('white wine',),
#   42.0),
#  ('cake',
#   'pasta',
#   'shrimp'): (('brownies', 'eggs', 'mineral water', 'tomato juice'), 33.0),
#  ('milk', 'salmon', 'shrimp', 'spaghetti'): (('cake',), 60.0),
#  ('cake', 'milk', 'mineral water', 'soup'): (('oil',), 82.5),
#  ('cake', 'mineral water', 'soup', 'spaghetti'): (('chicken', 'oil'), 82.5),
#  ('mineral water', 'red wine', 'spaghetti'): (('eggs',), 30.0),
#  ('cooking oil', 'eggs', 'mineral water', 'red wine'): (('zucchini',),
#   73.33333333333333),
#  ('chocolate',
#   'cooking oil',
#   'mineral water',
#   'red wine'): (('eggs', 'pancakes', 'zucchini'), 33.0),
#  ('cooking oil',
#   'pancakes',
#   'red wine'): (('eggs', 'mineral water', 'zucchini'), 110.0),
#  ('eggs',
#   'pancakes',
#   'red wine'): (('cooking oil', 'mineral water', 'zucchini'), 110.0),
#  ('chocolate',
#   'cooking oil',
#   'eggs',
#   'red wine'): (('mineral water', 'pancakes', 'zucchini'), 33.0),
#  ('chocolate',
#   'eggs',
#   'mineral water',
#   'red wine'): (('cooking oil', 'pancakes', 'zucchini'), 33.0),
#  ('chocolate',
#   'cooking oil',
#   'eggs',
#   'mineral water',
#   'red wine'): (('pancakes', 'zucchini'), 33.0),
#  ('cooking oil',
#   'eggs',
#   'mineral water',
#   'pancakes'): (('chocolate', 'zucchini'), 33.0),
#  ('escalope', 'mineral water', 'soup'): (('frozen vegetables',),
#   30.333333333333332),
#  ('eggs', 'frozen vegetables', 'ground beef', 'milk'): (('light mayo',), 33.0),
#  ('chocolate',
#   'escalope',
#   'frozen vegetables',
#   'spaghetti'): (('fresh bread',), 60.0),
#  ('french fries',
#   'frozen vegetables',
#   'milk',
#   'spaghetti'): (('chocolate', 'low fat yogurt'), 42.0),
#  ('chocolate',
#   'french fries',
#   'frozen vegetables',
#   'spaghetti'): (('low fat yogurt', 'milk'), 42.0),
#  ('chocolate',
#   'french fries',
#   'frozen vegetables',
#   'milk',
#   'spaghetti'): (('low fat yogurt',), 42.0),
#  ('energy bar', 'milk', 'mineral water'): (('escalope',), 33.0),
#  ('chocolate',
#   'mineral water',
#   'pancakes',
#   'whole wheat rice'): (('eggs', 'zucchini'), 110.0),
#  ('chocolate',
#   'cooking oil',
#   'mineral water',
#   'whole wheat rice'): (('eggs', 'pancakes', 'zucchini'), 33.0),
#  ('chocolate', 'eggs', 'mineral water', 'whole wheat rice'): (('zucchini',),
#   110.0),
#  ('cake', 'cooking oil', 'milk'): (('escalope', 'french fries', 'zucchini'),
#   45.5),
#  ('champagne', 'chocolate', 'ground beef'): (('eggs', 'zucchini'), 52.5),
#  ('champagne',
#   'chocolate',
#   'eggs'): (('french fries', 'light mayo', 'pancakes', 'spaghetti'), 33.0),
#  ('champagne', 'ground beef', 'zucchini'): (('eggs',), 30.333333333333332),
#  ('chocolate', 'honey', 'strawberries'): (('mint',), 143.0),
#  ('fresh bread', 'milk', 'salmon'): (('mineral water',), 30.333333333333332),
#  ('ground beef', 'mineral water', 'salmon', 'spaghetti'): (('pancakes',),
#   39.0),
#  ('chocolate',
#   'eggs',
#   'milk',
#   'olive oil'): (('brownies', 'mineral water', 'spaghetti'), 60.0),
#  ('chocolate', 'eggs', 'milk', 'mineral water', 'spaghetti'): (('brownies',),
#   30.0),
#  ('chocolate', 'eggs', 'french fries', 'pancakes'): (('low fat yogurt',),
#   42.0),
#  ('chocolate',
#   'eggs',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('light mayo',), 33.0),
#  ('chocolate', 'eggs', 'french fries', 'spaghetti'): (('light mayo',), 55.0),
#  ('herb & pepper',
#   'hot dogs',
#   'whole wheat rice'): (('green tea', 'spaghetti'), 56.0),
#  ('hot dogs',
#   'spaghetti',
#   'whole wheat rice'): (('green tea', 'herb & pepper'), 56.0),
#  ('chocolate',
#   'escalope',
#   'spaghetti',
#   'whole wheat rice'): (('cookies', 'french fries'), 33.0),
#  ('herb & pepper', 'olive oil', 'spaghetti'): (('pancakes',), 55.0),
#  ('escalope', 'herb & pepper', 'milk', 'spaghetti'): (('chicken', 'pancakes'),
#   82.5),
#  ('escalope',
#   'mineral water',
#   'mushroom cream sauce'): (('champagne',
#    'chocolate',
#    'fresh bread',
#    'spaghetti'), 39.0),
#  ('chocolate',
#   'escalope',
#   'mineral water',
#   'mushroom cream sauce'): (('champagne', 'fresh bread', 'spaghetti'), 39.0),
#  ('champagne',
#   'chocolate',
#   'mineral water',
#   'spaghetti'): (('escalope', 'french fries', 'fresh bread'), 39.0),
#  ('champagne', 'chocolate', 'spaghetti'): (('escalope', 'fresh bread'), 71.5),
#  ('chocolate',
#   'mineral water',
#   'spaghetti',
#   'whole wheat rice'): (('mushroom cream sauce',), 45.5),
#  ('cooking oil', 'ground beef', 'pancakes'): (('light mayo',), 60.0),
#  ('candy bars', 'low fat yogurt', 'mineral water'): (('chocolate',), 35.0),
#  ('chicken', 'mineral water', 'pancakes', 'spaghetti'): (('cake',), 40.0),
#  ('chicken', 'chocolate', 'mineral water', 'spaghetti'): (('white wine',),
#   42.0),
#  ('chicken', 'french fries', 'tomato juice'): (('fresh bread',), 42.0),
#  ('cookies', 'french fries', 'green tea', 'milk'): (('white wine',), 39.0),
#  ('eggs', 'strawberries', 'white wine'): (('milk',), 30.333333333333332),
#  ('cooking oil', 'eggs', 'milk'): (('french fries',), 39.0),
#  ('chocolate',
#   'cottage cheese',
#   'french fries'): (('frozen smoothie', 'light mayo'), 52.5),
#  ('cottage cheese', 'french fries', 'frozen smoothie'): (('light mayo',),
#   227.5),
#  ('cottage cheese', 'french fries', 'light mayo'): (('frozen smoothie',),
#   30.333333333333332),
#  ('french fries', 'frozen smoothie', 'light mayo'): (('cottage cheese',),
#   30.333333333333332),
#  ('cottage cheese', 'eggs', 'frozen smoothie'): (('low fat yogurt',), 143.0),
#  ('frozen smoothie',
#   'milk',
#   'olive oil',
#   'spaghetti'): (('cake', 'chocolate', 'protein bar'), 33.0),
#  ('cake',
#   'chocolate',
#   'eggs',
#   'mineral water'): (('frozen smoothie', 'spaghetti'), 60.0),
#  ('champagne',
#   'olive oil',
#   'pancakes'): (('eggs', 'french fries', 'light mayo', 'spaghetti'), 33.0),
#  ('champagne',
#   'pancakes',
#   'spaghetti'): (('eggs', 'french fries', 'light mayo'), 66.0),
#  ('champagne', 'eggs', 'spaghetti'): (('french fries', 'light mayo'), 220.0),
#  ('champagne',
#   'eggs',
#   'pancakes',
#   'spaghetti'): (('french fries', 'light mayo'), 66.0),
#  ('champagne',
#   'eggs',
#   'pancakes'): (('french fries', 'light mayo', 'spaghetti'), 44.0),
#  ('french fries', 'olive oil', 'pancakes'): (('champagne', 'light mayo'),
#   73.33333333333333),
#  ('eggs',
#   'french fries',
#   'olive oil',
#   'spaghetti'): (('champagne', 'light mayo'), 73.33333333333333),
#  ('champagne',
#   'french fries',
#   'pancakes'): (('eggs', 'light mayo', 'spaghetti'), 66.0),
#  ('champagne',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('eggs', 'light mayo'), 66.0),
#  ('champagne',
#   'eggs',
#   'french fries',
#   'pancakes'): (('light mayo', 'spaghetti'), 66.0),
#  ('champagne', 'eggs', 'french fries', 'spaghetti'): (('light mayo',), 220.0),
#  ('champagne',
#   'eggs',
#   'french fries',
#   'pancakes',
#   'spaghetti'): (('light mayo',), 66.0),
#  ('champagne', 'french fries', 'spaghetti'): (('escalope', 'fresh bread'),
#   95.33333333333333),
#  ('champagne', 'chocolate', 'french fries'): (('escalope', 'fresh bread'),
#   95.33333333333333),
#  ('champagne',
#   'chocolate',
#   'french fries',
#   'spaghetti'): (('escalope', 'fresh bread', 'mineral water'), 39.0),
#  ('eggs',
#   'french fries',
#   'frozen smoothie'): (('fresh bread', 'mineral water'), 60.0),
#  ('chocolate', 'french fries', 'frozen smoothie'): (('fresh bread',), 112.0),
#  ('cookies', 'tomato juice'): (('fresh bread', 'low fat yogurt'), 52.5),
#  ('cookies', 'green tea', 'mineral water'): (('fresh bread',), 35.0),
#  ('champagne',
#   'french fries',
#   'mineral water'): (('chocolate', 'escalope', 'fresh bread'), 143.0),
#  ('escalope', 'french fries', 'mineral water'): (('low fat yogurt', 'milk'),
#   82.5),
#  ('escalope',
#   'french fries',
#   'mineral water',
#   'spaghetti'): (('chocolate', 'fresh bread'), 39.0),
#  ('escalope', 'mineral water', 'pancakes'): (('low fat yogurt', 'milk'), 82.5),
#  ('green tea', 'mineral water', 'tomato juice'): (('low fat yogurt',), 30.0),
#  ('chocolate',
#   'eggs',
#   'french fries',
#   'milk',
#   'spaghetti'): (('low fat yogurt',), 42.0),
#  ('eggs',
#   'french fries',
#   'milk',
#   'mineral water',
#   'spaghetti'): (('low fat yogurt',), 30.333333333333332),
#  ('eggs', 'escalope', 'french fries'): (('cookies',), 110.0),
#  ('eggs', 'escalope', 'french fries', 'spaghetti'): (('chocolate', 'cookies'),
#   33.0)}
